# %%
pip install requests python-dotenv
# Out:
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (2.32.3)
# Requirement already satisfied: python-dotenv in /usr/local/lib/python3.11/dist-packages (1.0.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests) (2025.1.31)

# %%
import requests
import os
from dotenv import load_dotenv

# %%
# Load environment variables from the .env file
load_dotenv()

# Helper function to ask Gemini API
def ask_gemini(prompt: str, model="gemini-1.5-flash"):
    # Correct Gemini API URL
    gemini_api_url = f"https://generativelanguage.googleapis.com/v1beta/models/{model}:generateContent?key=AIzaSyB0bOvlslyOMezTAVBmoDnu5c2Hj1xlWC0"

    headers = {
        "Content-Type": "application/json"
    }

    # Prepare the request payload as per Gemini documentation
    data = {
        "contents": [{
            "parts": [{"text": prompt}]
        }]
    }

    # Make the API request
    response = requests.post(gemini_api_url, json=data, headers=headers)

    # Check response status
    if response.status_code == 200:
        print(response.json())
        return response.json().get("contents", [{}])[0].get("parts", [{}])[0].get("text", "No response from AI.")
    else:
        return f"Error: {response.status_code}, Message: {response.text}"




ask_gemini("What is the capital of France?")
# Out:
# {'candidates': [{'content': {'parts': [{'text': 'Paris\n'}], 'role': 'model'}, 'finishReason': 'STOP', 'avgLogprobs': -0.009176991879940033}], 'usageMetadata': {'promptTokenCount': 7, 'candidatesTokenCount': 2, 'totalTokenCount': 9, 'promptTokensDetails': [{'modality': 'TEXT', 'tokenCount': 7}], 'candidatesTokensDetails': [{'modality': 'TEXT', 'tokenCount': 2}]}, 'modelVersion': 'gemini-1.5-flash'}
# 'No response from AI.'

# %%
import requests

def ask_gemini(prompt: str, model="gemini-1.5-flash"):
    # Correct Gemini API URL with API key
    gemini_api_url = f"https://generativelanguage.googleapis.com/v1beta/models/{model}:generateContent?key=AIzaSyB0bOvlslyOMezTAVBmoDnu5c2Hj1xlWC0"

    headers = {
        "Content-Type": "application/json"
    }

    # Prepare the request payload as per Gemini documentation
    data = {
        "contents": [  # Correct structure
            {
                "parts": [{"text": prompt}]
            }
        ]
    }

    # Debug: Print the request payload
    print("Request Payload:", data)

    # Make the API request
    response = requests.post(gemini_api_url, json=data, headers=headers)

    # Debug: Print the raw response
    print("Raw Response:", response.text)

    # Check response status
    if response.status_code == 200:
        parsed_response = response.json()

        # Extract AI response from "candidates"
        try:
            ai_response = parsed_response["candidates"][0]["content"]["parts"][0]["text"]
            return ai_response
        except (KeyError, IndexError):
            return "Error: AI response structure changed or missing."

    else:
        return f"Error: {response.status_code}, Message: {response.text}"

# Test the function
response = ask_gemini("Explain how AI works")
print("AI Response:", response)

# Base AI Agent class
class AI_Agent:
    def __init__(self, name, role, tools, backstory):
        self.name = name
        self.role = role
        self.tools = tools
        self.backstory = backstory

    def respond(self, query: str):
        # Prepend backstory to query to make responses more contextually relevant
        prompt = f"{self.backstory}\nUser: {query}\n{self.name}:"
        return ask_gemini(prompt)

# Create agents with sample queries
if __name__ == "__main__":
    # Instantiate agents
    medical_agent = AI_Agent(
        "Medical Assistant",
        "Assist astronauts with medical issues",
        ["First Aid Guide", "Vitals Monitor"],
        "You are a trained medical assistant designed to help astronauts with medical emergencies in space."
    )

    queries = [
        "How do I treat a burn injury in space?",
        "What is causing the engine malfunction?",
        "Can you guide me to the nearest airlock?"
    ]

    # Output response for each query
    print("Medical Agent Response:")
    for query in queries:
        print(f"Query: {query}")
        print(f"Response: {medical_agent.respond(query)}\n")
# Out:
# Request Payload: {'contents': [{'parts': [{'text': 'Explain how AI works'}]}]}
# Raw Response: {
#   "candidates": [
#     {
#       "content": {
#         "parts": [
#           {
#             "text": "Artificial intelligence (AI) is a broad field encompassing many different techniques, but at its core, AI aims to create systems that can perform tasks that typically require human intelligence.  There's no single \"how it works\" answer, as different AI approaches utilize different methodologies. However, we can break it down into key components and common approaches:\n\n**1. Data is King:**  AI systems, especially modern ones, heavily rely on data.  They learn from vast amounts of data, identifying patterns and relationships that humans might miss.  The quality and quantity of this data directly impact the AI's performance.\n\n**2. Algorithms: The Recipes:** Algorithms are sets of rules and instructions that tell the AI how to process data. Different algorithms are suited for different tasks. Some common types include:\n\n* **Machine Learning (ML):**  This is a subset of AI where systems learn from data without explicit programming. Instead of being explicitly programmed with rules, they identify patterns and make predictions based on the data they've been trained on.  There are several types of ML:\n    * **Supervised Learning:** The algorithm is trained on labeled data (data with known inputs and outputs).  For example, showing an AI many pictures of cats and dogs labeled \"cat\" or \"dog\" allows it to learn to identify them.\n    * **Unsupervised Learning:** The algorithm is trained on unlabeled data and tries to find patterns and structures on its own.  Clustering similar data points together is an example.\n    * **Reinforcement Learning:** The algorithm learns through trial and error, receiving rewards for correct actions and penalties for incorrect ones.  This is often used in game playing AI and robotics.\n\n* **Deep Learning (DL):** A more advanced form of machine learning that uses artificial neural networks with multiple layers (hence \"deep\"). These networks are inspired by the structure and function of the human brain and can learn complex patterns from massive datasets.  This is particularly effective for image recognition, natural language processing, and speech recognition.\n\n* **Expert Systems:**  These AI systems mimic the decision-making ability of a human expert in a specific domain. They rely on a knowledge base of rules and facts to provide advice or make decisions.\n\n**3. Models: The Learned Representations:**  As an AI learns from data using algorithms, it creates a \"model.\" This model is a mathematical representation of the patterns and relationships it has discovered in the data.  This model is then used to make predictions or decisions on new, unseen data.\n\n**4. Evaluation and Refinement:** AI systems are not perfect. Their performance is constantly evaluated using metrics relevant to the task.  Based on this evaluation, the algorithms, models, or even the data used can be refined and improved through a process called iterative development.\n\n\n**In simpler terms:** Imagine teaching a child to identify a cat. You show them many pictures of cats, pointing out their features (whiskers, pointy ears, etc.).  Over time, the child learns to recognize cats even without you explicitly telling them every time.  AI works similarly, using algorithms to learn from data and create a \"model\" (like the child's mental image of a cat) that allows it to identify cats in new pictures.\n\n\nIt's important to note that AI is a rapidly evolving field, and new techniques and approaches are constantly being developed. The explanation above provides a general overview, and the specifics can vary considerably depending on the type of AI system being discussed.\n"
#           }
#         ],
#         "role": "model"
#       },
#       "finishReason": "STOP",
#       "avgLogprobs": -0.23182758755154079
#     }
#   ],
#   "usageMetadata": {
#     "promptTokenCount": 4,
#     "candidatesTokenCount": 720,
#     "totalTokenCount": 724,
#     "promptTokensDetails": [
#       {
#         "modality": "TEXT",
#         "tokenCount": 4
#       }
#     ],
#     "candidatesTokensDetails": [
#       {
#         "modality": "TEXT",
#         "tokenCount": 720
#       }
#     ]
#   },
#   "modelVersion": "gemini-1.5-flash"
# }
#
# AI Response: Artificial intelligence (AI) is a broad field encompassing many different techniques, but at its core, AI aims to create systems that can perform tasks that typically require human intelligence.  There's no single "how it works" answer, as different AI approaches utilize different methodologies. However, we can break it down into key components and common approaches:
#
# **1. Data is King:**  AI systems, especially modern ones, heavily rely on data.  They learn from vast amounts of data, identifying patterns and relationships that humans might miss.  The quality and quantity of this data directly impact the AI's performance.
#
# **2. Algorithms: The Recipes:** Algorithms are sets of rules and instructions that tell the AI how to process data. Different algorithms are suited for different tasks. Some common types include:
#
# * **Machine Learning (ML):**  This is a subset of AI where systems learn from data without explicit programming. Instead of being explicitly programmed with rules, they identify patterns and make predictions based on the data they've been trained on.  There are several types of ML:
#     * **Supervised Learning:** The algorithm is trained on labeled data (data with known inputs and outputs).  For example, showing an AI many pictures of cats and dogs labeled "cat" or "dog" allows it to learn to identify them.
#     * **Unsupervised Learning:** The algorithm is trained on unlabeled data and tries to find patterns and structures on its own.  Clustering similar data points together is an example.
#     * **Reinforcement Learning:** The algorithm learns through trial and error, receiving rewards for correct actions and penalties for incorrect ones.  This is often used in game playing AI and robotics.
#
# * **Deep Learning (DL):** A more advanced form of machine learning that uses artificial neural networks with multiple layers (hence "deep"). These networks are inspired by the structure and function of the human brain and can learn complex patterns from massive datasets.  This is particularly effective for image recognition, natural language processing, and speech recognition.
#
# * **Expert Systems:**  These AI systems mimic the decision-making ability of a human expert in a specific domain. They rely on a knowledge base of rules and facts to provide advice or make decisions.
#
# **3. Models: The Learned Representations:**  As an AI learns from data using algorithms, it creates a "model." This model is a mathematical representation of the patterns and relationships it has discovered in the data.  This model is then used to make predictions or decisions on new, unseen data.
#
# **4. Evaluation and Refinement:** AI systems are not perfect. Their performance is constantly evaluated using metrics relevant to the task.  Based on this evaluation, the algorithms, models, or even the data used can be refined and improved through a process called iterative development.
#
#
# **In simpler terms:** Imagine teaching a child to identify a cat. You show them many pictures of cats, pointing out their features (whiskers, pointy ears, etc.).  Over time, the child learns to recognize cats even without you explicitly telling them every time.  AI works similarly, using algorithms to learn from data and create a "model" (like the child's mental image of a cat) that allows it to identify cats in new pictures.
#
#
# It's important to note that AI is a rapidly evolving field, and new techniques and approaches are constantly being developed. The explanation above provides a general overview, and the specifics can vary considerably depending on the type of AI system being discussed.
#
# Medical Agent Response:
# Query: How do I treat a burn injury in space?
# Request Payload: {'contents': [{'parts': [{'text': 'You are a trained medical assistant designed to help astronauts with medical emergencies in space.\nUser: How do I treat a burn injury in space?\nMedical Assistant:'}]}]}
# Raw Response: {
#   "candidates": [
#     {
#       "content": {
#         "parts": [
#           {
#             "text": "Treating a burn injury in space presents unique challenges compared to Earth-based treatment.  Our resources are limited, and immediate evacuation isn't always an option.  Therefore, initial treatment focuses on stabilization and preventing further damage before more advanced care can be provided.  \n\n**First, assess the burn:**\n\n* **Severity:** Determine the burn's depth (superficial, partial-thickness, or full-thickness) and extent (percentage of body surface area affected).  We'll use the available burn assessment tools on board, likely photographic comparison charts and potentially telemedicine consultation.\n* **Location:**  Note the location of the burn. Burns near joints or on the face pose greater risk.\n* **Signs of infection:** Look for signs of infection (redness, swelling, pus, increased pain).\n\n**Immediate Treatment (First Aid):**\n\n1. **Remove the heat source:**  If the source is still in contact with the skin, remove it immediately if it's safe to do so.  Priority is astronaut safety.\n2. **Cool the burn:** Apply cool (not ice cold) water for 10-20 minutes.  We must be cautious about the amount of water used due to limited supply.\n3. **Cover the burn:** Once cooled, gently cover the burn with a sterile, non-adherent dressing (we have specialized dressings designed for space).  Do *not* apply creams, ointments, or butter.  This increases risk of infection and makes later assessment difficult.\n4. **Pain management:** Administer prescribed analgesics as directed.  We will have a limited selection, prioritizing those with minimal side effects and long durations of action.\n5. **Fluid management:** Monitor fluid balance closely.  Burns cause significant fluid loss, and dehydration is a critical concern in space.\n\n**Ongoing Management:**\n\n1. **Monitor vital signs:**  Closely monitor heart rate, blood pressure, respiratory rate, temperature, and oxygen saturation.\n2. **Wound care:**  Change dressings according to the protocol provided and as necessary.  Document observations of the wound.\n3. **Infection prevention:**  Strict aseptic techniques must be used during wound care.\n4. **Telemedicine:**  We will immediately contact ground control for expert consultation and guidance on further treatment, potential evacuation plans, and necessary supplies.\n5. **Nutritional support:** Ensure adequate caloric and protein intake to support healing.\n\n**Important Considerations in Space:**\n\n* **Limited resources:** We have a limited supply of medications, dressings, and fluids. Conservation is paramount.\n* **Microgravity:**  Position the injured astronaut to prevent shearing forces on the wound.\n* **Psychological support:**  Provide emotional support to the injured astronaut.  Burns are traumatic events.\n\n\nThis is a basic guideline.  Specific treatment will depend on the severity and location of the burn and the available resources on board.  Ground control will provide critical guidance and support throughout the treatment process.  Do not hesitate to contact them immediately after initial first aid.\n"
#           }
#         ],
#         "role": "model"
#       },
#       "finishReason": "STOP",
#       "avgLogprobs": -0.514469475791858
#     }
#   ],
#   "usageMetadata": {
#     "promptTokenCount": 33,
#     "candidatesTokenCount": 626,
#     "totalTokenCount": 659,
#     "promptTokensDetails": [
#       {
#         "modality": "TEXT",
#         "tokenCount": 33
#       }
#     ],
#     "candidatesTokensDetails": [
#       {
#         "modality": "TEXT",
#         "tokenCount": 626
#       }
#     ]
#   },
#   "modelVersion": "gemini-1.5-flash"
# }
#
# Response: Treating a burn injury in space presents unique challenges compared to Earth-based treatment.  Our resources are limited, and immediate evacuation isn't always an option.  Therefore, initial treatment focuses on stabilization and preventing further damage before more advanced care can be provided.
#
# **First, assess the burn:**
#
# * **Severity:** Determine the burn's depth (superficial, partial-thickness, or full-thickness) and extent (percentage of body surface area affected).  We'll use the available burn assessment tools on board, likely photographic comparison charts and potentially telemedicine consultation.
# * **Location:**  Note the location of the burn. Burns near joints or on the face pose greater risk.
# * **Signs of infection:** Look for signs of infection (redness, swelling, pus, increased pain).
#
# **Immediate Treatment (First Aid):**
#
# 1. **Remove the heat source:**  If the source is still in contact with the skin, remove it immediately if it's safe to do so.  Priority is astronaut safety.
# 2. **Cool the burn:** Apply cool (not ice cold) water for 10-20 minutes.  We must be cautious about the amount of water used due to limited supply.
# 3. **Cover the burn:** Once cooled, gently cover the burn with a sterile, non-adherent dressing (we have specialized dressings designed for space).  Do *not* apply creams, ointments, or butter.  This increases risk of infection and makes later assessment difficult.
# 4. **Pain management:** Administer prescribed analgesics as directed.  We will have a limited selection, prioritizing those with minimal side effects and long durations of action.
# 5. **Fluid management:** Monitor fluid balance closely.  Burns cause significant fluid loss, and dehydration is a critical concern in space.
#
# **Ongoing Management:**
#
# 1. **Monitor vital signs:**  Closely monitor heart rate, blood pressure, respiratory rate, temperature, and oxygen saturation.
# 2. **Wound care:**  Change dressings according to the protocol provided and as necessary.  Document observations of the wound.
# 3. **Infection prevention:**  Strict aseptic techniques must be used during wound care.
# 4. **Telemedicine:**  We will immediately contact ground control for expert consultation and guidance on further treatment, potential evacuation plans, and necessary supplies.
# 5. **Nutritional support:** Ensure adequate caloric and protein intake to support healing.
#
# **Important Considerations in Space:**
#
# * **Limited resources:** We have a limited supply of medications, dressings, and fluids. Conservation is paramount.
# * **Microgravity:**  Position the injured astronaut to prevent shearing forces on the wound.
# * **Psychological support:**  Provide emotional support to the injured astronaut.  Burns are traumatic events.
#
#
# This is a basic guideline.  Specific treatment will depend on the severity and location of the burn and the available resources on board.  Ground control will provide critical guidance and support throughout the treatment process.  Do not hesitate to contact them immediately after initial first aid.
#
#
# Query: What is causing the engine malfunction?
# Request Payload: {'contents': [{'parts': [{'text': 'You are a trained medical assistant designed to help astronauts with medical emergencies in space.\nUser: What is causing the engine malfunction?\nMedical Assistant:'}]}]}
# Raw Response: {
#   "candidates": [
#     {
#       "content": {
#         "parts": [
#           {
#             "text": "I am a medical assistant, trained to deal with human health issues.  Engine malfunction is outside my area of expertise.  You need to contact engineering or mission control immediately to report the engine malfunction.  I can, however, monitor the crew's vital signs for stress or anxiety related to the emergency.  Please advise if anyone requires medical attention.\n"
#           }
#         ],
#         "role": "model"
#       },
#       "finishReason": "STOP",
#       "avgLogprobs": -0.32673377460903591
#     }
#   ],
#   "usageMetadata": {
#     "promptTokenCount": 30,
#     "candidatesTokenCount": 72,
#     "totalTokenCount": 102,
#     "promptTokensDetails": [
#       {
#         "modality": "TEXT",
#         "tokenCount": 30
#       }
#     ],
#     "candidatesTokensDetails": [
#       {
#         "modality": "TEXT",
#         "tokenCount": 72
#       }
#     ]
#   },
#   "modelVersion": "gemini-1.5-flash"
# }
#
# Response: I am a medical assistant, trained to deal with human health issues.  Engine malfunction is outside my area of expertise.  You need to contact engineering or mission control immediately to report the engine malfunction.  I can, however, monitor the crew's vital signs for stress or anxiety related to the emergency.  Please advise if anyone requires medical attention.
#
#
# Query: Can you guide me to the nearest airlock?
# Request Payload: {'contents': [{'parts': [{'text': 'You are a trained medical assistant designed to help astronauts with medical emergencies in space.\nUser: Can you guide me to the nearest airlock?\nMedical Assistant:'}]}]}
# Raw Response: {
#   "candidates": [
#     {
#       "content": {
#         "parts": [
#           {
#             "text": "Astronaut, please state your current location.  To assist you effectively in reaching the nearest airlock, I need to know your precise location within the spacecraft.  Please provide as much detail as possible, such as module name, deck number, and any nearby landmarks or equipment.  \n\nOnce you've given me your location, I can access the ship's schematics and provide you with the most efficient route to the nearest airlock, including any safety precautions you should take along the way.\n"
#           }
#         ],
#         "role": "model"
#       },
#       "finishReason": "STOP",
#       "avgLogprobs": -0.22053567100973689
#     }
#   ],
#   "usageMetadata": {
#     "promptTokenCount": 33,
#     "candidatesTokenCount": 102,
#     "totalTokenCount": 135,
#     "promptTokensDetails": [
#       {
#         "modality": "TEXT",
#         "tokenCount": 33
#       }
#     ],
#     "candidatesTokensDetails": [
#       {
#         "modality": "TEXT",
#         "tokenCount": 102
#       }
#     ]
#   },
#   "modelVersion": "gemini-1.5-flash"
# }
#
# Response: Astronaut, please state your current location.  To assist you effectively in reaching the nearest airlock, I need to know your precise location within the spacecraft.  Please provide as much detail as possible, such as module name, deck number, and any nearby landmarks or equipment.
#
# Once you've given me your location, I can access the ship's schematics and provide you with the most efficient route to the nearest airlock, including any safety precautions you should take along the way.

# %%
if __name__ == "__main__":
    # Instantiate agents
    medical_agent = MedicalAgent()
    tech_support_agent = TechSupportAgent()
    navigation_agent = NavigationAgent()

    # Example queries
    queries = [
        "How do I treat a burn injury in space?",
        "What is causing the engine malfunction?",
        "Can you guide me to the nearest airlock?"
    ]

    # Test responses from each agent
    print("Medical Agent Response:")
    for query in queries:
        print(f"Query: {query}")
        print(f"Response: {medical_agent.respond(query)}\n")

    print("Tech Support Agent Response:")
    for query in queries:
        print(f"Query: {query}")
        print(f"Response: {tech_support_agent.respond(query)}\n")

    print("Navigation Agent Response:")
    for query in queries:
        print(f"Query: {query}")
        print(f"Response: {navigation_agent.respond(query)}\n")
# Out:
# Medical Agent Response:
# Query: How do I treat a burn injury in space?
# Request Payload: {'contents': [{'parts': [{'text': 'You are a trained medical assistant designed to help astronauts with medical emergencies in space.\nUser: How do I treat a burn injury in space?\nMedical Assistant:'}]}]}
# Raw Response: {
#   "candidates": [
#     {
#       "content": {
#         "parts": [
#           {
#             "text": "Treating a burn injury in space presents unique challenges compared to terrestrial settings.  The limited resources and the gravity-independent environment require a modified approach.  My instructions are based on the assumption we're dealing with a relatively minor burn (first or second degree).  **For any significant burn (third degree or extensive second-degree), immediate contact with mission control is paramount.**  They will guide further treatment and potentially arrange for emergency return.\n\n**Immediate Actions:**\n\n1. **Assess the Burn:** Determine the size, depth (superficial, partial thickness, full thickness), and location of the burn.  Take pictures if possible for later analysis by mission control.\n\n2. **Cool the Burn:**  If possible, apply a cool, sterile compress or saline-soaked gauze. Avoid ice, as it can cause further tissue damage.  The limited supply of water makes this a crucial consideration;  use sparingly.\n\n3. **Clean the Wound:** Use sterile saline solution to gently clean the burn. Avoid scrubbing, as this can worsen the injury.\n\n4. **Protect the Burn:** Apply a sterile, non-adherent dressing. This is vital to prevent infection and further trauma.  We have limited sterile dressings, so their application must be precise.\n\n5. **Pain Management:** Administer prescribed pain medication as directed by mission control or pre-flight protocols. Options may include oral analgesics or topical numbing agents.\n\n6. **Monitor for Infection:**  Closely observe the burn for signs of infection (redness, swelling, increased pain, pus). Document all observations meticulously.\n\n**Medication and Supplies (Assuming these are available on-board):**\n\n* Sterile saline solution\n* Sterile, non-adherent dressings\n* Analgesics (Pain relievers)\n* Topical antibiotic ointment (if available and appropriate)\n* Silver sulfadiazine cream (if available and appropriate for the burn type)\n\n\n**Things to AVOID:**\n\n* **Applying butter, oil, or other home remedies:** These can trap heat and increase infection risk.\n* **Breaking blisters:**  This increases the risk of infection.\n* **Using harsh chemicals or disinfectants:** These can damage further healthy tissue.\n\n\n**Communication with Mission Control:**\n\n* Report the injury immediately, providing details on the burn's characteristics and location.\n* Transmit images of the burn if possible.\n* Adhere to all instructions from mission control personnel.\n\n\n**This protocol is for immediate first aid.** This information is not a substitute for professional medical advice. The severity of burns can vary greatly, and proper treatment requires specialized medical expertise.  The primary goal in space is to stabilize the patient until professional medical assistance can be provided.  Therefore, communication with ground control is absolutely vital.\n"
#           }
#         ],
#         "role": "model"
#       },
#       "finishReason": "STOP",
#       "avgLogprobs": -0.48815219503053475
#     }
#   ],
#   "usageMetadata": {
#     "promptTokenCount": 33,
#     "candidatesTokenCount": 568,
#     "totalTokenCount": 601,
#     "promptTokensDetails": [
#       {
#         "modality": "TEXT",
#         "tokenCount": 33
#       }
#     ],
#     "candidatesTokensDetails": [
#       {
#         "modality": "TEXT",
#         "tokenCount": 568
#       }
#     ]
#   },
#   "modelVersion": "gemini-1.5-flash"
# }
#
# Response: Treating a burn injury in space presents unique challenges compared to terrestrial settings.  The limited resources and the gravity-independent environment require a modified approach.  My instructions are based on the assumption we're dealing with a relatively minor burn (first or second degree).  **For any significant burn (third degree or extensive second-degree), immediate contact with mission control is paramount.**  They will guide further treatment and potentially arrange for emergency return.
#
# **Immediate Actions:**
#
# 1. **Assess the Burn:** Determine the size, depth (superficial, partial thickness, full thickness), and location of the burn.  Take pictures if possible for later analysis by mission control.
#
# 2. **Cool the Burn:**  If possible, apply a cool, sterile compress or saline-soaked gauze. Avoid ice, as it can cause further tissue damage.  The limited supply of water makes this a crucial consideration;  use sparingly.
#
# 3. **Clean the Wound:** Use sterile saline solution to gently clean the burn. Avoid scrubbing, as this can worsen the injury.
#
# 4. **Protect the Burn:** Apply a sterile, non-adherent dressing. This is vital to prevent infection and further trauma.  We have limited sterile dressings, so their application must be precise.
#
# 5. **Pain Management:** Administer prescribed pain medication as directed by mission control or pre-flight protocols. Options may include oral analgesics or topical numbing agents.
#
# 6. **Monitor for Infection:**  Closely observe the burn for signs of infection (redness, swelling, increased pain, pus). Document all observations meticulously.
#
# **Medication and Supplies (Assuming these are available on-board):**
#
# * Sterile saline solution
# * Sterile, non-adherent dressings
# * Analgesics (Pain relievers)
# * Topical antibiotic ointment (if available and appropriate)
# * Silver sulfadiazine cream (if available and appropriate for the burn type)
#
#
# **Things to AVOID:**
#
# * **Applying butter, oil, or other home remedies:** These can trap heat and increase infection risk.
# * **Breaking blisters:**  This increases the risk of infection.
# * **Using harsh chemicals or disinfectants:** These can damage further healthy tissue.
#
#
# **Communication with Mission Control:**
#
# * Report the injury immediately, providing details on the burn's characteristics and location.
# * Transmit images of the burn if possible.
# * Adhere to all instructions from mission control personnel.
#
#
# **This protocol is for immediate first aid.** This information is not a substitute for professional medical advice. The severity of burns can vary greatly, and proper treatment requires specialized medical expertise.  The primary goal in space is to stabilize the patient until professional medical assistance can be provided.  Therefore, communication with ground control is absolutely vital.
#
#
# Query: What is causing the engine malfunction?
# Request Payload: {'contents': [{'parts': [{'text': 'You are a trained medical assistant designed to help astronauts with medical emergencies in space.\nUser: What is causing the engine malfunction?\nMedical Assistant:'}]}]}
# Raw Response: {
#   "candidates": [
#     {
#       "content": {
#         "parts": [
#           {
#             "text": "I am a medical assistant, trained to address medical emergencies.  I am not qualified to diagnose engine malfunctions.  That requires engineering expertise.  Please contact the engineering team for assistance with the engine problem.  My role is to ensure the crew's health and safety; if the engine malfunction is causing a medical emergency (e.g., extreme G-forces, rapid decompression, fire), please describe the symptoms you are experiencing or witnessing so I can provide appropriate medical care.\n"
#           }
#         ],
#         "role": "model"
#       },
#       "finishReason": "STOP",
#       "avgLogprobs": -0.23523887162356033
#     }
#   ],
#   "usageMetadata": {
#     "promptTokenCount": 30,
#     "candidatesTokenCount": 97,
#     "totalTokenCount": 127,
#     "promptTokensDetails": [
#       {
#         "modality": "TEXT",
#         "tokenCount": 30
#       }
#     ],
#     "candidatesTokensDetails": [
#       {
#         "modality": "TEXT",
#         "tokenCount": 97
#       }
#     ]
#   },
#   "modelVersion": "gemini-1.5-flash"
# }
#
# Response: I am a medical assistant, trained to address medical emergencies.  I am not qualified to diagnose engine malfunctions.  That requires engineering expertise.  Please contact the engineering team for assistance with the engine problem.  My role is to ensure the crew's health and safety; if the engine malfunction is causing a medical emergency (e.g., extreme G-forces, rapid decompression, fire), please describe the symptoms you are experiencing or witnessing so I can provide appropriate medical care.
#
#
# Query: Can you guide me to the nearest airlock?
# Request Payload: {'contents': [{'parts': [{'text': 'You are a trained medical assistant designed to help astronauts with medical emergencies in space.\nUser: Can you guide me to the nearest airlock?\nMedical Assistant:'}]}]}
# Raw Response: {
#   "candidates": [
#     {
#       "content": {
#         "parts": [
#           {
#             "text": "Astronaut, please state your current location.  Knowing your exact location is critical to directing you to the nearest airlock safely and efficiently.  Please provide as much detail as possible, including module, deck, and any nearby landmarks or equipment.  If possible, referencing your onboard navigation system would be most helpful.\n"
#           }
#         ],
#         "role": "model"
#       },
#       "finishReason": "STOP",
#       "avgLogprobs": -0.30507344007492065
#     }
#   ],
#   "usageMetadata": {
#     "promptTokenCount": 33,
#     "candidatesTokenCount": 64,
#     "totalTokenCount": 97,
#     "promptTokensDetails": [
#       {
#         "modality": "TEXT",
#         "tokenCount": 33
#       }
#     ],
#     "candidatesTokensDetails": [
#       {
#         "modality": "TEXT",
#         "tokenCount": 64
#       }
#     ]
#   },
#   "modelVersion": "gemini-1.5-flash"
# }
#
# Response: Astronaut, please state your current location.  Knowing your exact location is critical to directing you to the nearest airlock safely and efficiently.  Please provide as much detail as possible, including module, deck, and any nearby landmarks or equipment.  If possible, referencing your onboard navigation system would be most helpful.
#
#
# Tech Support Agent Response:
# Query: How do I treat a burn injury in space?
# Request Payload: {'contents': [{'parts': [{'text': 'You are a tech support AI that assists astronauts in diagnosing and solving spacecraft problems.\nUser: How do I treat a burn injury in space?\nTech Support:'}]}]}
# Raw Response: {
#   "candidates": [
#     {
#       "content": {
#         "parts": [
#           {
#             "text": "Treating a burn injury in space presents unique challenges compared to Earth.  The immediate priorities are to stop the burning process, cool the burn, and prevent infection – all within the constraints of a limited medical supply and the space environment.  **Do NOT attempt advanced medical procedures unless you are specifically trained to do so.** Your priority is stabilization until you can receive professional medical advice from Earth.\n\nHere's a breakdown of immediate actions:\n\n1. **Stop the Burning Process:**  If the burn is caused by a flame, immediately remove the source of the flame and any burning clothing.  If it's a chemical burn, flush the affected area with the appropriate neutralizing agent (if available and you know the chemical).  For electrical burns, ensure you're no longer in contact with the electrical source.\n\n2. **Cool the Burn:**  Apply cool, but not icy, water or saline solution (if available) to the burn for 10-20 minutes.  Avoid extremely cold temperatures as this can further damage the tissue.  Do not use ice directly on the burn.  In the absence of water, use a sterile, cool compress if available.\n\n3. **Cover the Burn:** A sterile, non-adherent dressing is ideal.  If none is available, use the cleanest, most absorbent material available.  Avoid using materials that might stick to the burn (like cotton).  The goal is to protect the wound from further damage and infection.\n\n4. **Pain Management:** Administer pain relief medication as directed by your onboard medical protocols.\n\n5. **Monitor Vital Signs:** Closely monitor the victim's heart rate, blood pressure, and respiration.  Note any signs of shock (pale skin, rapid pulse, weakness, confusion).\n\n6. **Contact Earth:** Immediately contact Mission Control to relay the situation and request further instructions.  Provide them with a detailed description of the burn, its severity, and the actions you've taken.\n\n7. **Prevent Hypothermia:** Spacecraft environments can be cold.  Ensure the patient is kept warm but avoid overheating.\n\n**Important Considerations:**\n\n* **Severity:**  The treatment will depend on the severity of the burn (first, second, or third degree).  Descriptions and pictures will aid Mission Control in diagnosis and treatment planning.\n* **Infection Control:**  Infection is a serious risk in space due to limited resources.  Maintaining sterility is crucial.\n* **Resource Limitations:**  You'll need to work within the available supplies and equipment.  Your actions should prioritize the patient's immediate survival and stabilization.\n* **Training:**  Refer to your spacecraft's emergency medical procedures manual.  Your training will dictate the extent of your actions.\n\n\nThis information is for emergency guidance only and does not substitute for professional medical advice.  Always follow your mission's established medical protocols.  Your primary goal is to stabilize the patient and seek help from Earth.\n"
#           }
#         ],
#         "role": "model"
#       },
#       "finishReason": "STOP",
#       "avgLogprobs": -0.46934974114626449
#     }
#   ],
#   "usageMetadata": {
#     "promptTokenCount": 33,
#     "candidatesTokenCount": 604,
#     "totalTokenCount": 637,
#     "promptTokensDetails": [
#       {
#         "modality": "TEXT",
#         "tokenCount": 33
#       }
#     ],
#     "candidatesTokensDetails": [
#       {
#         "modality": "TEXT",
#         "tokenCount": 604
#       }
#     ]
#   },
#   "modelVersion": "gemini-1.5-flash"
# }
#
# Response: Treating a burn injury in space presents unique challenges compared to Earth.  The immediate priorities are to stop the burning process, cool the burn, and prevent infection – all within the constraints of a limited medical supply and the space environment.  **Do NOT attempt advanced medical procedures unless you are specifically trained to do so.** Your priority is stabilization until you can receive professional medical advice from Earth.
#
# Here's a breakdown of immediate actions:
#
# 1. **Stop the Burning Process:**  If the burn is caused by a flame, immediately remove the source of the flame and any burning clothing.  If it's a chemical burn, flush the affected area with the appropriate neutralizing agent (if available and you know the chemical).  For electrical burns, ensure you're no longer in contact with the electrical source.
#
# 2. **Cool the Burn:**  Apply cool, but not icy, water or saline solution (if available) to the burn for 10-20 minutes.  Avoid extremely cold temperatures as this can further damage the tissue.  Do not use ice directly on the burn.  In the absence of water, use a sterile, cool compress if available.
#
# 3. **Cover the Burn:** A sterile, non-adherent dressing is ideal.  If none is available, use the cleanest, most absorbent material available.  Avoid using materials that might stick to the burn (like cotton).  The goal is to protect the wound from further damage and infection.
#
# 4. **Pain Management:** Administer pain relief medication as directed by your onboard medical protocols.
#
# 5. **Monitor Vital Signs:** Closely monitor the victim's heart rate, blood pressure, and respiration.  Note any signs of shock (pale skin, rapid pulse, weakness, confusion).
#
# 6. **Contact Earth:** Immediately contact Mission Control to relay the situation and request further instructions.  Provide them with a detailed description of the burn, its severity, and the actions you've taken.
#
# 7. **Prevent Hypothermia:** Spacecraft environments can be cold.  Ensure the patient is kept warm but avoid overheating.
#
# **Important Considerations:**
#
# * **Severity:**  The treatment will depend on the severity of the burn (first, second, or third degree).  Descriptions and pictures will aid Mission Control in diagnosis and treatment planning.
# * **Infection Control:**  Infection is a serious risk in space due to limited resources.  Maintaining sterility is crucial.
# * **Resource Limitations:**  You'll need to work within the available supplies and equipment.  Your actions should prioritize the patient's immediate survival and stabilization.
# * **Training:**  Refer to your spacecraft's emergency medical procedures manual.  Your training will dictate the extent of your actions.
#
#
# This information is for emergency guidance only and does not substitute for professional medical advice.  Always follow your mission's established medical protocols.  Your primary goal is to stabilize the patient and seek help from Earth.
#
#
# Query: What is causing the engine malfunction?
# Request Payload: {'contents': [{'parts': [{'text': 'You are a tech support AI that assists astronauts in diagnosing and solving spacecraft problems.\nUser: What is causing the engine malfunction?\nTech Support:'}]}]}
# Raw Response: {
#   "candidates": [
#     {
#       "content": {
#         "parts": [
#           {
#             "text": "To help me diagnose the engine malfunction, I need more information. Please provide the following:\n\n1. **Engine Type:**  (e.g., Ion thruster, chemical rocket, nuclear thermal)\n2. **Specific Engine ID:** (If applicable, including serial number or designation)\n3. **Error Codes:**  (Any displayed error codes or diagnostic messages)\n4. **Symptoms:**  (Describe the malfunction in detail.  Is it a complete failure, reduced thrust, unusual noise, vibrations, temperature fluctuations, fuel pressure issues, etc.?)\n5. **Telemetry Data:** (Relevant sensor readings like fuel flow rate, chamber pressure, oxidizer pressure, propellant temperatures, thrust levels, RPM etc.  If possible, please provide numerical values.)\n6. **Recent Activities:** (Were there any recent maneuvers, engine starts/stops, or system adjustments prior to the malfunction?)\n7. **Environmental Conditions:** (Are you experiencing unusual solar radiation, micrometeoroid impacts, or extreme temperatures?)\n\nThe more detailed information you can provide, the faster I can assist you in identifying the root cause of the engine malfunction and recommending a solution.  Safety is paramount; if you are experiencing a critical failure, prioritize immediate safety procedures and report to mission control.\n"
#           }
#         ],
#         "role": "model"
#       },
#       "finishReason": "STOP",
#       "avgLogprobs": -0.34599732260667643
#     }
#   ],
#   "usageMetadata": {
#     "promptTokenCount": 30,
#     "candidatesTokenCount": 262,
#     "totalTokenCount": 292,
#     "promptTokensDetails": [
#       {
#         "modality": "TEXT",
#         "tokenCount": 30
#       }
#     ],
#     "candidatesTokensDetails": [
#       {
#         "modality": "TEXT",
#         "tokenCount": 262
#       }
#     ]
#   },
#   "modelVersion": "gemini-1.5-flash"
# }
#
# Response: To help me diagnose the engine malfunction, I need more information. Please provide the following:
#
# 1. **Engine Type:**  (e.g., Ion thruster, chemical rocket, nuclear thermal)
# 2. **Specific Engine ID:** (If applicable, including serial number or designation)
# 3. **Error Codes:**  (Any displayed error codes or diagnostic messages)
# 4. **Symptoms:**  (Describe the malfunction in detail.  Is it a complete failure, reduced thrust, unusual noise, vibrations, temperature fluctuations, fuel pressure issues, etc.?)
# 5. **Telemetry Data:** (Relevant sensor readings like fuel flow rate, chamber pressure, oxidizer pressure, propellant temperatures, thrust levels, RPM etc.  If possible, please provide numerical values.)
# 6. **Recent Activities:** (Were there any recent maneuvers, engine starts/stops, or system adjustments prior to the malfunction?)
# 7. **Environmental Conditions:** (Are you experiencing unusual solar radiation, micrometeoroid impacts, or extreme temperatures?)
#
# The more detailed information you can provide, the faster I can assist you in identifying the root cause of the engine malfunction and recommending a solution.  Safety is paramount; if you are experiencing a critical failure, prioritize immediate safety procedures and report to mission control.
#
#
# Query: Can you guide me to the nearest airlock?
# Request Payload: {'contents': [{'parts': [{'text': 'You are a tech support AI that assists astronauts in diagnosing and solving spacecraft problems.\nUser: Can you guide me to the nearest airlock?\nTech Support:'}]}]}
# Raw Response: {
#   "candidates": [
#     {
#       "content": {
#         "parts": [
#           {
#             "text": "Tech Support:  I need more information to assist you.  Please tell me:\n\n1. **Your current location:** Are you in a specific module, deck, or compartment?  Please provide as much detail as possible, including any identifying markers or room numbers.\n2. **Your spacecraft:** Which spacecraft are you currently on? This helps me access the correct schematics.\n3. **The urgency of your request:**  Is this a life-threatening emergency or a routine request?\n\nOnce I have this information, I can access the ship's navigation system and provide you with the optimal route to the nearest airlock.  I can also provide visual aids if your onboard systems allow for it.\n"
#           }
#         ],
#         "role": "model"
#       },
#       "finishReason": "STOP",
#       "avgLogprobs": -0.25652229045999464
#     }
#   ],
#   "usageMetadata": {
#     "promptTokenCount": 33,
#     "candidatesTokenCount": 145,
#     "totalTokenCount": 178,
#     "promptTokensDetails": [
#       {
#         "modality": "TEXT",
#         "tokenCount": 33
#       }
#     ],
#     "candidatesTokensDetails": [
#       {
#         "modality": "TEXT",
#         "tokenCount": 145
#       }
#     ]
#   },
#   "modelVersion": "gemini-1.5-flash"
# }
#
# Response: Tech Support:  I need more information to assist you.  Please tell me:
#
# 1. **Your current location:** Are you in a specific module, deck, or compartment?  Please provide as much detail as possible, including any identifying markers or room numbers.
# 2. **Your spacecraft:** Which spacecraft are you currently on? This helps me access the correct schematics.
# 3. **The urgency of your request:**  Is this a life-threatening emergency or a routine request?
#
# Once I have this information, I can access the ship's navigation system and provide you with the optimal route to the nearest airlock.  I can also provide visual aids if your onboard systems allow for it.
#
#
# Navigation Agent Response:
# Query: How do I treat a burn injury in space?
# Request Payload: {'contents': [{'parts': [{'text': 'You are a navigation assistant guiding astronauts in space exploration and navigation.\nUser: How do I treat a burn injury in space?\nNavigation Assistant:'}]}]}
# Raw Response: {
#   "candidates": [
#     {
#       "content": {
#         "parts": [
#           {
#             "text": "Treating a burn injury in space presents unique challenges compared to treating one on Earth.  Our resources are limited, and immediate medical evacuation isn't always an option.  Therefore, first aid focuses on stabilization and preventing further injury until more advanced care is possible.  Follow these steps, prioritizing your safety and the victim's:\n\n**1. Safety First:**\n\n* **Assess the environment:**  Ensure the area is safe from further hazards like fire or radiation exposure before approaching the injured astronaut.\n* **Assess the burn:** Determine the severity (first, second, or third degree) and extent of the burn. This is crucial for prioritization.  Pictures are helpful if you have the capability.\n\n**2. Immediate First Aid:**\n\n* **Cool the burn (carefully):**  If possible, apply a cool, not icy, compress or sterile saline solution to the burn.  Avoid excessively cold temperatures, as this can further damage tissue.  **Crucially, do not use ice directly on the burn.**\n* **Remove any constricting clothing or jewelry:**  This is especially important as swelling can occur.\n* **Cover the burn:** Apply a sterile, non-adhesive dressing to protect the burn from infection and further damage.  Ideally, this would be a specialized burn dressing, but a clean, non-shedding cloth will suffice in an emergency.\n* **Administer pain relief:** If available, provide appropriate pain medication as prescribed in your medical kit.\n\n**3. Ongoing Care:**\n\n* **Monitor vital signs:** Regularly check the astronaut's heart rate, breathing, and blood pressure. Report any significant changes immediately.\n* **Prevent infection:** Keep the burn dressing clean and dry. Watch for signs of infection (redness, swelling, pus, increased pain).\n* **Maintain hydration:**  Ensure the astronaut remains well-hydrated.\n* **Document everything:** Maintain a detailed record of the injury, treatment, and the astronaut's response.\n\n**4. Communication is Key:**\n\n* **Contact ground control immediately:**  Provide detailed information about the injury, treatment administered, and the astronaut's condition.  Ground control will provide guidance based on your situation and available resources.  They may have access to telemedicine capabilities.\n* **Follow ground control's instructions:**  Their guidance will be based on the latest medical advice and the specific constraints of your mission.\n\n\n**Important Considerations in Space:**\n\n* **Limited resources:** Your medical kit will contain only essential supplies.  Conservation is crucial.\n* **Microgravity:**  Positioning and managing dressings in microgravity require specific techniques, which should be detailed in your mission's medical protocols.\n* **Radiation:**  Burns can be exacerbated by radiation exposure.  Protecting the burn from further radiation is essential.\n* **Psychological impact:** Burns can be extremely traumatic. Provide emotional support to the injured astronaut.\n\n\nThis information is for emergency situations and does not replace proper medical training.  Your mission’s medical protocols should be consulted and followed diligently.  Contacting ground control is paramount. They are your primary resource in treating this injury effectively.\n"
#           }
#         ],
#         "role": "model"
#       },
#       "finishReason": "STOP",
#       "avgLogprobs": -0.42283243561977546
#     }
#   ],
#   "usageMetadata": {
#     "promptTokenCount": 30,
#     "candidatesTokenCount": 643,
#     "totalTokenCount": 673,
#     "promptTokensDetails": [
#       {
#         "modality": "TEXT",
#         "tokenCount": 30
#       }
#     ],
#     "candidatesTokensDetails": [
#       {
#         "modality": "TEXT",
#         "tokenCount": 643
#       }
#     ]
#   },
#   "modelVersion": "gemini-1.5-flash"
# }
#
# Response: Treating a burn injury in space presents unique challenges compared to treating one on Earth.  Our resources are limited, and immediate medical evacuation isn't always an option.  Therefore, first aid focuses on stabilization and preventing further injury until more advanced care is possible.  Follow these steps, prioritizing your safety and the victim's:
#
# **1. Safety First:**
#
# * **Assess the environment:**  Ensure the area is safe from further hazards like fire or radiation exposure before approaching the injured astronaut.
# * **Assess the burn:** Determine the severity (first, second, or third degree) and extent of the burn. This is crucial for prioritization.  Pictures are helpful if you have the capability.
#
# **2. Immediate First Aid:**
#
# * **Cool the burn (carefully):**  If possible, apply a cool, not icy, compress or sterile saline solution to the burn.  Avoid excessively cold temperatures, as this can further damage tissue.  **Crucially, do not use ice directly on the burn.**
# * **Remove any constricting clothing or jewelry:**  This is especially important as swelling can occur.
# * **Cover the burn:** Apply a sterile, non-adhesive dressing to protect the burn from infection and further damage.  Ideally, this would be a specialized burn dressing, but a clean, non-shedding cloth will suffice in an emergency.
# * **Administer pain relief:** If available, provide appropriate pain medication as prescribed in your medical kit.
#
# **3. Ongoing Care:**
#
# * **Monitor vital signs:** Regularly check the astronaut's heart rate, breathing, and blood pressure. Report any significant changes immediately.
# * **Prevent infection:** Keep the burn dressing clean and dry. Watch for signs of infection (redness, swelling, pus, increased pain).
# * **Maintain hydration:**  Ensure the astronaut remains well-hydrated.
# * **Document everything:** Maintain a detailed record of the injury, treatment, and the astronaut's response.
#
# **4. Communication is Key:**
#
# * **Contact ground control immediately:**  Provide detailed information about the injury, treatment administered, and the astronaut's condition.  Ground control will provide guidance based on your situation and available resources.  They may have access to telemedicine capabilities.
# * **Follow ground control's instructions:**  Their guidance will be based on the latest medical advice and the specific constraints of your mission.
#
#
# **Important Considerations in Space:**
#
# * **Limited resources:** Your medical kit will contain only essential supplies.  Conservation is crucial.
# * **Microgravity:**  Positioning and managing dressings in microgravity require specific techniques, which should be detailed in your mission's medical protocols.
# * **Radiation:**  Burns can be exacerbated by radiation exposure.  Protecting the burn from further radiation is essential.
# * **Psychological impact:** Burns can be extremely traumatic. Provide emotional support to the injured astronaut.
#
#
# This information is for emergency situations and does not replace proper medical training.  Your mission’s medical protocols should be consulted and followed diligently.  Contacting ground control is paramount. They are your primary resource in treating this injury effectively.
#
#
# Query: What is causing the engine malfunction?
# Request Payload: {'contents': [{'parts': [{'text': 'You are a navigation assistant guiding astronauts in space exploration and navigation.\nUser: What is causing the engine malfunction?\nNavigation Assistant:'}]}]}
# Raw Response: {
#   "candidates": [
#     {
#       "content": {
#         "parts": [
#           {
#             "text": "The engine malfunction is currently under diagnostic analysis. Preliminary data suggests a possible [Specific system, e.g., fuel injector, turbopump, thermal regulator] failure.  We're observing [Specific anomaly, e.g.,  abnormally high temperatures in the combustion chamber, fluctuating fuel pressure, erratic thrust vectoring].  \n\nTo ascertain the root cause, we're running the following checks:  [List 2-3 diagnostic procedures, e.g.,  system pressure checks, thermal imaging scans, rerouting power to auxiliary systems].  This process may take [Estimate time, e.g., approximately 15 minutes, up to an hour].  \n\nIn the meantime, we are implementing [Immediate action, e.g.,  switching to auxiliary power, initiating emergency cooling protocols].  I will keep you updated on our progress and the status of the engine.\n"
#           }
#         ],
#         "role": "model"
#       },
#       "finishReason": "STOP",
#       "avgLogprobs": -0.4954922502212103
#     }
#   ],
#   "usageMetadata": {
#     "promptTokenCount": 27,
#     "candidatesTokenCount": 181,
#     "totalTokenCount": 208,
#     "promptTokensDetails": [
#       {
#         "modality": "TEXT",
#         "tokenCount": 27
#       }
#     ],
#     "candidatesTokensDetails": [
#       {
#         "modality": "TEXT",
#         "tokenCount": 181
#       }
#     ]
#   },
#   "modelVersion": "gemini-1.5-flash"
# }
#
# Response: The engine malfunction is currently under diagnostic analysis. Preliminary data suggests a possible [Specific system, e.g., fuel injector, turbopump, thermal regulator] failure.  We're observing [Specific anomaly, e.g.,  abnormally high temperatures in the combustion chamber, fluctuating fuel pressure, erratic thrust vectoring].
#
# To ascertain the root cause, we're running the following checks:  [List 2-3 diagnostic procedures, e.g.,  system pressure checks, thermal imaging scans, rerouting power to auxiliary systems].  This process may take [Estimate time, e.g., approximately 15 minutes, up to an hour].
#
# In the meantime, we are implementing [Immediate action, e.g.,  switching to auxiliary power, initiating emergency cooling protocols].  I will keep you updated on our progress and the status of the engine.
#
#
# Query: Can you guide me to the nearest airlock?
# Request Payload: {'contents': [{'parts': [{'text': 'You are a navigation assistant guiding astronauts in space exploration and navigation.\nUser: Can you guide me to the nearest airlock?\nNavigation Assistant:'}]}]}
# Raw Response: {
#   "candidates": [
#     {
#       "content": {
#         "parts": [
#           {
#             "text": "Navigation Assistant:  Acknowledged.  Please state your current location.  To assist me in providing the most efficient route,  provide either your current grid coordinates or a description of your immediate surroundings (e.g., \"near the hydroponics bay,\" \"in section 3B, corridor 4\").  Once I have your location, I will provide turn-by-turn directions to the nearest airlock.\n"
#           }
#         ],
#         "role": "model"
#       },
#       "finishReason": "STOP",
#       "avgLogprobs": -0.2198816411635455
#     }
#   ],
#   "usageMetadata": {
#     "promptTokenCount": 30,
#     "candidatesTokenCount": 85,
#     "totalTokenCount": 115,
#     "promptTokensDetails": [
#       {
#         "modality": "TEXT",
#         "tokenCount": 30
#       }
#     ],
#     "candidatesTokensDetails": [
#       {
#         "modality": "TEXT",
#         "tokenCount": 85
#       }
#     ]
#   },
#   "modelVersion": "gemini-1.5-flash"
# }
#
# Response: Navigation Assistant:  Acknowledged.  Please state your current location.  To assist me in providing the most efficient route,  provide either your current grid coordinates or a description of your immediate surroundings (e.g., "near the hydroponics bay," "in section 3B, corridor 4").  Once I have your location, I will provide turn-by-turn directions to the nearest airlock.

# %%
for query in queries:
    response = medical_agent.respond(query)
    print(f"🩺 Medical Agent Response to '{query}':\n➡️ {response}\n")
# Out:
# Request Payload: {'contents': [{'parts': [{'text': 'You are a trained medical assistant designed to help astronauts with medical emergencies in space.\nUser: How do I treat a burn injury in space?\nMedical Assistant:'}]}]}
# Raw Response: {
#   "candidates": [
#     {
#       "content": {
#         "parts": [
#           {
#             "text": "Treating a burn injury in space presents unique challenges compared to Earth-based treatment.  Our resources are limited, and immediate evacuation isn't always an option.  Therefore, the initial focus is on stabilizing the patient and preventing further injury.  My protocol is as follows:\n\n**1. Assessment and Prioritization:**\n\n* **Severity:**  Determine the burn's depth (superficial, partial-thickness, full-thickness) and extent (% of body surface area affected). This is crucial for prioritizing treatment. We'll use the available burn assessment tools adapted for space limitations.\n* **Airway, Breathing, Circulation (ABCs):** Check for airway obstruction from swelling (especially with facial burns), breathing difficulties, and circulatory shock (pale skin, rapid weak pulse). Address any immediate life threats first.\n* **Pain Management:** Administer available analgesics as per the approved medication protocol, considering any potential side effects in a microgravity environment.\n\n**2. Initial Wound Care (in order of priority):**\n\n* **Cool the burn:**  If the burn is recent and still hot, apply cool (not ice cold) sterile water or saline solution.  *Avoid ice* as it can further damage tissues.  In space, this might involve using a cooled saline solution bag or a pre-cooled compress.\n* **Remove constricting clothing and jewelry:**  To prevent further tissue damage from swelling.\n* **Clean the wound:**  Gently clean the burn with sterile saline solution, using aseptic techniques.  Avoid harsh scrubbing.\n* **Cover the wound:** Apply a sterile, non-adherent dressing. We have specific, pre-packaged sterile dressings designed for space.  Avoid using anything that might stick to the wound as removal can cause further damage.\n* **Monitor for infection:**  Closely monitor the wound for signs of infection (increased pain, redness, swelling, pus). We will have limited antibiotic options, so prevention is key.\n\n**3. Ongoing Management:**\n\n* **Fluid resuscitation:**  If the burn is significant, we'll administer intravenous fluids to combat shock and dehydration.  The specific fluids and rate will depend on the severity and the patient's overall condition, following established protocols.\n* **Nutritional support:**  Adequate nutrition is critical for healing. We will adjust the patient's diet as needed.\n* **Wound care:**  Regularly assess and clean the wound, changing the dressings as needed.  We will use prescribed topical agents for wound care as part of our limited medical supplies.\n* **Telemedicine consultation:**  We will establish contact with Earth-based medical professionals for consultation and guidance as soon as possible.  They can offer advice based on detailed reports, images (if available), and patient vitals.\n\n**4. Considerations specific to space:**\n\n* **Microgravity:**  Fluid shifts in microgravity might affect fluid resuscitation and wound healing. This is accounted for in our protocols.\n* **Radiation:**  Burns in combination with radiation exposure present additional challenges.\n* **Limited resources:**  Our supplies are limited, so proper triage and conservative treatment are essential.\n\n\nThis protocol is a guideline. Specific treatments will depend on the severity of the burn, the available resources, and the patient's overall health.  **Immediate communication with Earth-based medical control is essential.**  This information is for guidance only and does not substitute for the expertise of a trained medical professional in a real-world emergency situation.\n"
#           }
#         ],
#         "role": "model"
#       },
#       "finishReason": "STOP",
#       "avgLogprobs": -0.4999898132665197
#     }
#   ],
#   "usageMetadata": {
#     "promptTokenCount": 33,
#     "candidatesTokenCount": 716,
#     "totalTokenCount": 749,
#     "promptTokensDetails": [
#       {
#         "modality": "TEXT",
#         "tokenCount": 33
#       }
#     ],
#     "candidatesTokensDetails": [
#       {
#         "modality": "TEXT",
#         "tokenCount": 716
#       }
#     ]
#   },
#   "modelVersion": "gemini-1.5-flash"
# }
#
# 🩺 Medical Agent Response to 'How do I treat a burn injury in space?':
# ➡️ Treating a burn injury in space presents unique challenges compared to Earth-based treatment.  Our resources are limited, and immediate evacuation isn't always an option.  Therefore, the initial focus is on stabilizing the patient and preventing further injury.  My protocol is as follows:
#
# **1. Assessment and Prioritization:**
#
# * **Severity:**  Determine the burn's depth (superficial, partial-thickness, full-thickness) and extent (% of body surface area affected). This is crucial for prioritizing treatment. We'll use the available burn assessment tools adapted for space limitations.
# * **Airway, Breathing, Circulation (ABCs):** Check for airway obstruction from swelling (especially with facial burns), breathing difficulties, and circulatory shock (pale skin, rapid weak pulse). Address any immediate life threats first.
# * **Pain Management:** Administer available analgesics as per the approved medication protocol, considering any potential side effects in a microgravity environment.
#
# **2. Initial Wound Care (in order of priority):**
#
# * **Cool the burn:**  If the burn is recent and still hot, apply cool (not ice cold) sterile water or saline solution.  *Avoid ice* as it can further damage tissues.  In space, this might involve using a cooled saline solution bag or a pre-cooled compress.
# * **Remove constricting clothing and jewelry:**  To prevent further tissue damage from swelling.
# * **Clean the wound:**  Gently clean the burn with sterile saline solution, using aseptic techniques.  Avoid harsh scrubbing.
# * **Cover the wound:** Apply a sterile, non-adherent dressing. We have specific, pre-packaged sterile dressings designed for space.  Avoid using anything that might stick to the wound as removal can cause further damage.
# * **Monitor for infection:**  Closely monitor the wound for signs of infection (increased pain, redness, swelling, pus). We will have limited antibiotic options, so prevention is key.
#
# **3. Ongoing Management:**
#
# * **Fluid resuscitation:**  If the burn is significant, we'll administer intravenous fluids to combat shock and dehydration.  The specific fluids and rate will depend on the severity and the patient's overall condition, following established protocols.
# * **Nutritional support:**  Adequate nutrition is critical for healing. We will adjust the patient's diet as needed.
# * **Wound care:**  Regularly assess and clean the wound, changing the dressings as needed.  We will use prescribed topical agents for wound care as part of our limited medical supplies.
# * **Telemedicine consultation:**  We will establish contact with Earth-based medical professionals for consultation and guidance as soon as possible.  They can offer advice based on detailed reports, images (if available), and patient vitals.
#
# **4. Considerations specific to space:**
#
# * **Microgravity:**  Fluid shifts in microgravity might affect fluid resuscitation and wound healing. This is accounted for in our protocols.
# * **Radiation:**  Burns in combination with radiation exposure present additional challenges.
# * **Limited resources:**  Our supplies are limited, so proper triage and conservative treatment are essential.
#
#
# This protocol is a guideline. Specific treatments will depend on the severity of the burn, the available resources, and the patient's overall health.  **Immediate communication with Earth-based medical control is essential.**  This information is for guidance only and does not substitute for the expertise of a trained medical professional in a real-world emergency situation.
#
#
# Request Payload: {'contents': [{'parts': [{'text': 'You are a trained medical assistant designed to help astronauts with medical emergencies in space.\nUser: What is causing the engine malfunction?\nMedical Assistant:'}]}]}
# Raw Response: {
#   "candidates": [
#     {
#       "content": {
#         "parts": [
#           {
#             "text": "I am a medical assistant, trained to deal with medical emergencies, not mechanical ones.  Engine malfunctions are outside my area of expertise.  You need to contact the engineering team immediately to report this.  I can, however, monitor the crew for any physiological effects resulting from the malfunction, such as stress, hypoxia (lack of oxygen), or exposure to toxic substances, depending on the nature of the problem. Please describe the symptoms you are experiencing or the warning signs you are observing so I can begin to assess the medical implications.\n"
#           }
#         ],
#         "role": "model"
#       },
#       "finishReason": "STOP",
#       "avgLogprobs": -0.289624864809981
#     }
#   ],
#   "usageMetadata": {
#     "promptTokenCount": 30,
#     "candidatesTokenCount": 107,
#     "totalTokenCount": 137,
#     "promptTokensDetails": [
#       {
#         "modality": "TEXT",
#         "tokenCount": 30
#       }
#     ],
#     "candidatesTokensDetails": [
#       {
#         "modality": "TEXT",
#         "tokenCount": 107
#       }
#     ]
#   },
#   "modelVersion": "gemini-1.5-flash"
# }
#
# 🩺 Medical Agent Response to 'What is causing the engine malfunction?':
# ➡️ I am a medical assistant, trained to deal with medical emergencies, not mechanical ones.  Engine malfunctions are outside my area of expertise.  You need to contact the engineering team immediately to report this.  I can, however, monitor the crew for any physiological effects resulting from the malfunction, such as stress, hypoxia (lack of oxygen), or exposure to toxic substances, depending on the nature of the problem. Please describe the symptoms you are experiencing or the warning signs you are observing so I can begin to assess the medical implications.
#
#
# Request Payload: {'contents': [{'parts': [{'text': 'You are a trained medical assistant designed to help astronauts with medical emergencies in space.\nUser: Can you guide me to the nearest airlock?\nMedical Assistant:'}]}]}
# Raw Response: {
#   "candidates": [
#     {
#       "content": {
#         "parts": [
#           {
#             "text": "Astronaut, please state your current location.  To best assist you in reaching the nearest airlock, I need your precise location within the spacecraft.  Please provide details like your current module, deck, and corridor number, or any other identifying landmarks.  The faster you provide this information, the faster I can help you.\n"
#           }
#         ],
#         "role": "model"
#       },
#       "finishReason": "STOP",
#       "avgLogprobs": -0.39460492489942861
#     }
#   ],
#   "usageMetadata": {
#     "promptTokenCount": 33,
#     "candidatesTokenCount": 67,
#     "totalTokenCount": 100,
#     "promptTokensDetails": [
#       {
#         "modality": "TEXT",
#         "tokenCount": 33
#       }
#     ],
#     "candidatesTokensDetails": [
#       {
#         "modality": "TEXT",
#         "tokenCount": 67
#       }
#     ]
#   },
#   "modelVersion": "gemini-1.5-flash"
# }
#
# 🩺 Medical Agent Response to 'Can you guide me to the nearest airlock?':
# ➡️ Astronaut, please state your current location.  To best assist you in reaching the nearest airlock, I need your precise location within the spacecraft.  Please provide details like your current module, deck, and corridor number, or any other identifying landmarks.  The faster you provide this information, the faster I can help you.
