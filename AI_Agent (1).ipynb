# %%
pip install requests python-dotenv
# Out:
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (2.32.3)
# Collecting python-dotenv
#   Downloading python_dotenv-1.0.1-py3-none-any.whl.metadata (23 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests) (2025.1.31)
# Downloading python_dotenv-1.0.1-py3-none-any.whl (19 kB)
# Installing collected packages: python-dotenv
# Successfully installed python-dotenv-1.0.1

# %%
import requests
import os
from dotenv import load_dotenv

# %%
# Load environment variables from the .env file
load_dotenv()

# Helper function to ask Gemini API
def ask_gemini(prompt: str, model="gemini-1.5-flash"):
    # Correct Gemini API URL
    gemini_api_url = f"https://generativelanguage.googleapis.com/v1beta/models/{model}:generateContent?key=AIzaSyB0bOvlslyOMezTAVBmoDnu5c2Hj1xlWC0"

    headers = {
        "Content-Type": "application/json"
    }

    # Prepare the request payload as per Gemini documentation
    data = {
        "contents": [{
            "parts": [{"text": prompt}]
        }]
    }

    # Make the API request
    response = requests.post(gemini_api_url, json=data, headers=headers)

    # Check response status
    if response.status_code == 200:
        print(response.json())
        return response.json().get("contents", [{}])[0].get("parts", [{}])[0].get("text", "No response from AI.")
    else:
        return f"Error: {response.status_code}, Message: {response.text}"




ask_gemini("What is the capital of France?")
# Out:
# {'candidates': [{'content': {'parts': [{'text': 'Paris\n'}], 'role': 'model'}, 'finishReason': 'STOP', 'avgLogprobs': -0.009176991879940033}], 'usageMetadata': {'promptTokenCount': 7, 'candidatesTokenCount': 2, 'totalTokenCount': 9, 'promptTokensDetails': [{'modality': 'TEXT', 'tokenCount': 7}], 'candidatesTokensDetails': [{'modality': 'TEXT', 'tokenCount': 2}]}, 'modelVersion': 'gemini-1.5-flash'}
# 'No response from AI.'

# %%
import requests

def ask_gemini(prompt: str, model="gemini-1.5-flash"):
    # Correct Gemini API URL with API key
    gemini_api_url = f"https://generativelanguage.googleapis.com/v1beta/models/{model}:generateContent?key=AIzaSyB0bOvlslyOMezTAVBmoDnu5c2Hj1xlWC0"

    headers = {
        "Content-Type": "application/json"
    }

    # Prepare the request payload as per Gemini documentation
    data = {
        "contents": [  # Correct structure
            {
                "parts": [{"text": prompt}]
            }
        ]
    }

    # Debug: Print the request payload
    print("Request Payload:", data)

    # Make the API request
    response = requests.post(gemini_api_url, json=data, headers=headers)

    # Debug: Print the raw response
    print("Raw Response:", response.text)

    # Check response status
    if response.status_code == 200:
        parsed_response = response.json()

        # Extract AI response from "candidates"
        try:
            ai_response = parsed_response["candidates"][0]["content"]["parts"][0]["text"]
            return ai_response
        except (KeyError, IndexError):
            return "Error: AI response structure changed or missing."

    else:
        return f"Error: {response.status_code}, Message: {response.text}"

# Test the function
response = ask_gemini("Explain how AI works")
print("AI Response:", response)

# Base AI Agent class
class AI_Agent:
    def __init__(self, name, role, tools, backstory):
        self.name = name
        self.role = role
        self.tools = tools
        self.backstory = backstory

    def respond(self, query: str):
        # Prepend backstory to query to make responses more contextually relevant
        prompt = f"{self.backstory}\nUser: {query}\n{self.name}:"
        return ask_gemini(prompt)

# Create agents with sample queries
if __name__ == "__main__":
    # Instantiate agents
    medical_agent = AI_Agent(
        "Medical Assistant",
        "Assist astronauts with medical issues",
        ["First Aid Guide", "Vitals Monitor"],
        "You are a trained medical assistant designed to help astronauts with medical emergencies in space."
    )

    queries = [
        "How do I treat a burn injury in space?",
        "What is causing the engine malfunction?",
        "Can you guide me to the nearest airlock?"
    ]

    # Output response for each query
    print("Medical Agent Response:")
    for query in queries:
        print(f"Query: {query}")
        print(f"Response: {medical_agent.respond(query)}\n")
# Out:
# Request Payload: {'contents': [{'parts': [{'text': 'Explain how AI works'}]}]}
# Raw Response: {
#   "candidates": [
#     {
#       "content": {
#         "parts": [
#           {
#             "text": "AI works by combining massive amounts of data with fast, iterative processing and intelligent algorithms, allowing the software to learn automatically from patterns or features in the data.  There's no single \"how it works\" because AI encompasses a wide range of techniques, but here's a breakdown of some key aspects:\n\n**1. Data Acquisition and Preparation:**\n\n* **Gathering Data:** AI systems require vast quantities of data relevant to the task they're designed to perform. This data can be structured (like tables in a database) or unstructured (like images, text, or audio).\n* **Data Cleaning and Preprocessing:**  Raw data is often messy and incomplete.  This stage involves cleaning the data, handling missing values, and transforming it into a format suitable for the AI algorithms.  This might involve techniques like normalization, feature scaling, and encoding categorical variables.\n\n**2. Choosing an AI Approach:**\n\nThis depends on the problem being solved.  Common approaches include:\n\n* **Machine Learning (ML):**  This is the most common approach.  ML algorithms learn from data without explicit programming.  Different types of ML exist:\n    * **Supervised Learning:** The algorithm is trained on labeled data (data with known inputs and outputs).  Examples include classification (e.g., spam detection) and regression (e.g., predicting house prices).\n    * **Unsupervised Learning:** The algorithm learns from unlabeled data, identifying patterns and structures.  Examples include clustering (grouping similar data points) and dimensionality reduction (reducing the number of variables).\n    * **Reinforcement Learning:** The algorithm learns through trial and error, interacting with an environment and receiving rewards or penalties for its actions.  Examples include game playing and robotics.\n* **Deep Learning (DL):** A subset of ML that uses artificial neural networks with multiple layers (hence \"deep\").  These networks are particularly good at processing complex data like images and natural language.  Examples include image recognition, natural language processing, and speech recognition.\n* **Expert Systems:**  These systems mimic the decision-making ability of a human expert by using a set of rules and knowledge bases.  They are less common now due to the limitations of rule-based systems compared to data-driven approaches.\n\n**3. Training the AI Model:**\n\nThis involves feeding the prepared data to the chosen algorithm.  The algorithm adjusts its internal parameters (weights and biases in neural networks) to minimize errors and improve its performance. This process can involve complex mathematical optimization techniques like gradient descent.\n\n**4. Evaluation and Testing:**\n\nThe trained model's performance is evaluated using various metrics, depending on the task (e.g., accuracy, precision, recall, F1-score).  Testing involves applying the model to unseen data to assess its generalization ability (how well it performs on data it hasn't seen before).\n\n**5. Deployment and Iteration:**\n\nOnce the model performs satisfactorily, it's deployed to a real-world application.  However, AI is rarely a one-time process.  Models often need to be retrained and updated regularly with new data to maintain accuracy and adapt to changing circumstances.\n\n**In short:** AI works by leveraging algorithms to find patterns and relationships in data, allowing it to make predictions, decisions, or take actions without explicit programming for each scenario.  The success of an AI system depends heavily on the quality and quantity of the data used to train it, as well as the choice of appropriate algorithms and architecture.\n"
#           }
#         ],
#         "role": "model"
#       },
#       "finishReason": "STOP",
#       "citationMetadata": {
#         "citationSources": [
#           {
#             "startIndex": 30,
#             "endIndex": 178,
#             "uri": "https://www.aidataanalytics.network/data-science-ai/articles/applied-ai-enterprise-data-science"
#           }
#         ]
#       },
#       "avgLogprobs": -0.21997741191297893
#     }
#   ],
#   "usageMetadata": {
#     "promptTokenCount": 4,
#     "candidatesTokenCount": 721,
#     "totalTokenCount": 725,
#     "promptTokensDetails": [
#       {
#         "modality": "TEXT",
#         "tokenCount": 4
#       }
#     ],
#     "candidatesTokensDetails": [
#       {
#         "modality": "TEXT",
#         "tokenCount": 721
#       }
#     ]
#   },
#   "modelVersion": "gemini-1.5-flash"
# }
#
# AI Response: AI works by combining massive amounts of data with fast, iterative processing and intelligent algorithms, allowing the software to learn automatically from patterns or features in the data.  There's no single "how it works" because AI encompasses a wide range of techniques, but here's a breakdown of some key aspects:
#
# **1. Data Acquisition and Preparation:**
#
# * **Gathering Data:** AI systems require vast quantities of data relevant to the task they're designed to perform. This data can be structured (like tables in a database) or unstructured (like images, text, or audio).
# * **Data Cleaning and Preprocessing:**  Raw data is often messy and incomplete.  This stage involves cleaning the data, handling missing values, and transforming it into a format suitable for the AI algorithms.  This might involve techniques like normalization, feature scaling, and encoding categorical variables.
#
# **2. Choosing an AI Approach:**
#
# This depends on the problem being solved.  Common approaches include:
#
# * **Machine Learning (ML):**  This is the most common approach.  ML algorithms learn from data without explicit programming.  Different types of ML exist:
#     * **Supervised Learning:** The algorithm is trained on labeled data (data with known inputs and outputs).  Examples include classification (e.g., spam detection) and regression (e.g., predicting house prices).
#     * **Unsupervised Learning:** The algorithm learns from unlabeled data, identifying patterns and structures.  Examples include clustering (grouping similar data points) and dimensionality reduction (reducing the number of variables).
#     * **Reinforcement Learning:** The algorithm learns through trial and error, interacting with an environment and receiving rewards or penalties for its actions.  Examples include game playing and robotics.
# * **Deep Learning (DL):** A subset of ML that uses artificial neural networks with multiple layers (hence "deep").  These networks are particularly good at processing complex data like images and natural language.  Examples include image recognition, natural language processing, and speech recognition.
# * **Expert Systems:**  These systems mimic the decision-making ability of a human expert by using a set of rules and knowledge bases.  They are less common now due to the limitations of rule-based systems compared to data-driven approaches.
#
# **3. Training the AI Model:**
#
# This involves feeding the prepared data to the chosen algorithm.  The algorithm adjusts its internal parameters (weights and biases in neural networks) to minimize errors and improve its performance. This process can involve complex mathematical optimization techniques like gradient descent.
#
# **4. Evaluation and Testing:**
#
# The trained model's performance is evaluated using various metrics, depending on the task (e.g., accuracy, precision, recall, F1-score).  Testing involves applying the model to unseen data to assess its generalization ability (how well it performs on data it hasn't seen before).
#
# **5. Deployment and Iteration:**
#
# Once the model performs satisfactorily, it's deployed to a real-world application.  However, AI is rarely a one-time process.  Models often need to be retrained and updated regularly with new data to maintain accuracy and adapt to changing circumstances.
#
# **In short:** AI works by leveraging algorithms to find patterns and relationships in data, allowing it to make predictions, decisions, or take actions without explicit programming for each scenario.  The success of an AI system depends heavily on the quality and quantity of the data used to train it, as well as the choice of appropriate algorithms and architecture.
#
# Medical Agent Response:
# Query: How do I treat a burn injury in space?
# Request Payload: {'contents': [{'parts': [{'text': 'You are a trained medical assistant designed to help astronauts with medical emergencies in space.\nUser: How do I treat a burn injury in space?\nMedical Assistant:'}]}]}
# Raw Response: {
#   "candidates": [
#     {
#       "content": {
#         "parts": [
#           {
#             "text": "Treating a burn injury in space presents unique challenges compared to Earth.  Our resources are limited and immediate evacuation isn't an option.  The following protocol should be followed, prioritizing the severity of the burn:\n\n**First Assessment (Critical):**\n\n1. **Assess the severity:**  Determine the burn's depth (superficial, partial-thickness, or full-thickness) and extent (percentage of body surface area affected).  Use the available burn assessment tools in the onboard medical kit.  This dictates the urgency of treatment.\n2. **Assess for other injuries:**  Burns are often accompanied by other trauma. Check for fractures, inhalation injury (especially important with flame burns), and other wounds.\n3. **ABCs:**  Ensure the astronaut's airway, breathing, and circulation are stable.  Address any life-threatening issues first.  Administer oxygen as needed.\n\n\n**Treatment (Based on Severity & Available Resources):**\n\n* **Minor Burns (Superficial, 1st-degree):**\n    * **Cool the burn:**  If possible, use cool (not cold!) saline solution or sterile water compresses for 10-20 minutes to reduce pain and inflammation. Avoid ice, as it can worsen tissue damage.\n    * **Pain relief:** Administer analgesics as directed by the onboard medical protocols.\n    * **Topical treatment:** Apply a sterile, burn-specific ointment if available.  Otherwise, keep the area clean and covered with a sterile dressing.\n\n* **Moderate Burns (Partial-thickness, 2nd-degree):**\n    * **Cool the burn:** As above, using cool saline compresses.\n    * **Pain relief:** Administer stronger analgesics as needed.  Monitor for signs of infection.\n    * **Wound care:**  Keep the burn clean and covered with a sterile, non-adherent dressing to prevent infection.  Document the appearance and size of the wound regularly.\n    * **Fluid resuscitation:** Monitor for signs of dehydration. This is crucial, especially with large burns.\n\n\n* **Severe Burns (Full-thickness, 3rd-degree and deeper):**\n    * **Immediate stabilization:** This is a life-threatening emergency.  Prioritize ABCs and fluid resuscitation aggressively.\n    * **Pain management:** Strong analgesics will be necessary.\n    * **Wound care:**  Protect the burn from further damage with sterile dressings.  Avoid any attempts at debridement (removing dead tissue). This must be done by a physician if possible, and appropriate debridement materials may not be available.\n    * **Infection control:**  Strict aseptic techniques are crucial to prevent infection.\n    * **Telemedicine consultation:** Immediately contact ground control for guidance and to arrange for any possible intervention or modification to the mission plan.\n\n\n**General Considerations for Space Burn Treatment:**\n\n* **Limited resources:**  Conserve supplies.  Prioritize the most critical aspects of treatment.\n* **Infection prevention:**  Maintaining sterility is paramount in the closed environment of a spacecraft.\n* **Psychological support:**  Burns are traumatic. Provide emotional support to the astronaut.\n* **Documentation:**  Meticulously document all aspects of the assessment and treatment.  This information is vital for ground-based medical professionals and for future reference.\n\n**Important Note:** This information is for emergency guidance only.  Specific treatment protocols will vary depending on the spacecraft and its onboard medical supplies.  Always refer to the official medical protocols provided by your space agency.  This information does not replace the expertise of a trained physician.\n"
#           }
#         ],
#         "role": "model"
#       },
#       "finishReason": "STOP",
#       "avgLogprobs": -0.43566330306121376
#     }
#   ],
#   "usageMetadata": {
#     "promptTokenCount": 33,
#     "candidatesTokenCount": 741,
#     "totalTokenCount": 774,
#     "promptTokensDetails": [
#       {
#         "modality": "TEXT",
#         "tokenCount": 33
#       }
#     ],
#     "candidatesTokensDetails": [
#       {
#         "modality": "TEXT",
#         "tokenCount": 741
#       }
#     ]
#   },
#   "modelVersion": "gemini-1.5-flash"
# }
#
# Response: Treating a burn injury in space presents unique challenges compared to Earth.  Our resources are limited and immediate evacuation isn't an option.  The following protocol should be followed, prioritizing the severity of the burn:
#
# **First Assessment (Critical):**
#
# 1. **Assess the severity:**  Determine the burn's depth (superficial, partial-thickness, or full-thickness) and extent (percentage of body surface area affected).  Use the available burn assessment tools in the onboard medical kit.  This dictates the urgency of treatment.
# 2. **Assess for other injuries:**  Burns are often accompanied by other trauma. Check for fractures, inhalation injury (especially important with flame burns), and other wounds.
# 3. **ABCs:**  Ensure the astronaut's airway, breathing, and circulation are stable.  Address any life-threatening issues first.  Administer oxygen as needed.
#
#
# **Treatment (Based on Severity & Available Resources):**
#
# * **Minor Burns (Superficial, 1st-degree):**
#     * **Cool the burn:**  If possible, use cool (not cold!) saline solution or sterile water compresses for 10-20 minutes to reduce pain and inflammation. Avoid ice, as it can worsen tissue damage.
#     * **Pain relief:** Administer analgesics as directed by the onboard medical protocols.
#     * **Topical treatment:** Apply a sterile, burn-specific ointment if available.  Otherwise, keep the area clean and covered with a sterile dressing.
#
# * **Moderate Burns (Partial-thickness, 2nd-degree):**
#     * **Cool the burn:** As above, using cool saline compresses.
#     * **Pain relief:** Administer stronger analgesics as needed.  Monitor for signs of infection.
#     * **Wound care:**  Keep the burn clean and covered with a sterile, non-adherent dressing to prevent infection.  Document the appearance and size of the wound regularly.
#     * **Fluid resuscitation:** Monitor for signs of dehydration. This is crucial, especially with large burns.
#
#
# * **Severe Burns (Full-thickness, 3rd-degree and deeper):**
#     * **Immediate stabilization:** This is a life-threatening emergency.  Prioritize ABCs and fluid resuscitation aggressively.
#     * **Pain management:** Strong analgesics will be necessary.
#     * **Wound care:**  Protect the burn from further damage with sterile dressings.  Avoid any attempts at debridement (removing dead tissue). This must be done by a physician if possible, and appropriate debridement materials may not be available.
#     * **Infection control:**  Strict aseptic techniques are crucial to prevent infection.
#     * **Telemedicine consultation:** Immediately contact ground control for guidance and to arrange for any possible intervention or modification to the mission plan.
#
#
# **General Considerations for Space Burn Treatment:**
#
# * **Limited resources:**  Conserve supplies.  Prioritize the most critical aspects of treatment.
# * **Infection prevention:**  Maintaining sterility is paramount in the closed environment of a spacecraft.
# * **Psychological support:**  Burns are traumatic. Provide emotional support to the astronaut.
# * **Documentation:**  Meticulously document all aspects of the assessment and treatment.  This information is vital for ground-based medical professionals and for future reference.
#
# **Important Note:** This information is for emergency guidance only.  Specific treatment protocols will vary depending on the spacecraft and its onboard medical supplies.  Always refer to the official medical protocols provided by your space agency.  This information does not replace the expertise of a trained physician.
#
#
# Query: What is causing the engine malfunction?
# Request Payload: {'contents': [{'parts': [{'text': 'You are a trained medical assistant designed to help astronauts with medical emergencies in space.\nUser: What is causing the engine malfunction?\nMedical Assistant:'}]}]}
# Raw Response: {
#   "candidates": [
#     {
#       "content": {
#         "parts": [
#           {
#             "text": "I am a medical assistant, trained to deal with human medical emergencies.  I am not qualified to diagnose engine malfunctions.  That requires a trained engineer.  Please contact the engineering department immediately to report the engine malfunction.  I can, however, monitor the crew for any physiological effects that *might* be related to the malfunction, such as changes in G-force, cabin pressure, or exposure to toxins resulting from a potential system breach.  Please describe the nature of the malfunction and any observable symptoms among the crew so I can begin appropriate monitoring.\n"
#           }
#         ],
#         "role": "model"
#       },
#       "finishReason": "STOP",
#       "avgLogprobs": -0.35489957673209055
#     }
#   ],
#   "usageMetadata": {
#     "promptTokenCount": 30,
#     "candidatesTokenCount": 112,
#     "totalTokenCount": 142,
#     "promptTokensDetails": [
#       {
#         "modality": "TEXT",
#         "tokenCount": 30
#       }
#     ],
#     "candidatesTokensDetails": [
#       {
#         "modality": "TEXT",
#         "tokenCount": 112
#       }
#     ]
#   },
#   "modelVersion": "gemini-1.5-flash"
# }
#
# Response: I am a medical assistant, trained to deal with human medical emergencies.  I am not qualified to diagnose engine malfunctions.  That requires a trained engineer.  Please contact the engineering department immediately to report the engine malfunction.  I can, however, monitor the crew for any physiological effects that *might* be related to the malfunction, such as changes in G-force, cabin pressure, or exposure to toxins resulting from a potential system breach.  Please describe the nature of the malfunction and any observable symptoms among the crew so I can begin appropriate monitoring.
#
#
# Query: Can you guide me to the nearest airlock?
# Request Payload: {'contents': [{'parts': [{'text': 'You are a trained medical assistant designed to help astronauts with medical emergencies in space.\nUser: Can you guide me to the nearest airlock?\nMedical Assistant:'}]}]}
# Raw Response: {
#   "candidates": [
#     {
#       "content": {
#         "parts": [
#           {
#             "text": "Astronaut, please state your current location.  Knowing your precise location (module, deck, and specific room) is critical to guiding you to the nearest airlock safely and efficiently.  Also, please describe the nature of your medical emergency, if any.  This will help me determine the most appropriate route and prioritize your needs.  Do you have any mobility limitations?\n"
#           }
#         ],
#         "role": "model"
#       },
#       "finishReason": "STOP",
#       "avgLogprobs": -0.34832951897069026
#     }
#   ],
#   "usageMetadata": {
#     "promptTokenCount": 33,
#     "candidatesTokenCount": 76,
#     "totalTokenCount": 109,
#     "promptTokensDetails": [
#       {
#         "modality": "TEXT",
#         "tokenCount": 33
#       }
#     ],
#     "candidatesTokensDetails": [
#       {
#         "modality": "TEXT",
#         "tokenCount": 76
#       }
#     ]
#   },
#   "modelVersion": "gemini-1.5-flash"
# }
#
# Response: Astronaut, please state your current location.  Knowing your precise location (module, deck, and specific room) is critical to guiding you to the nearest airlock safely and efficiently.  Also, please describe the nature of your medical emergency, if any.  This will help me determine the most appropriate route and prioritize your needs.  Do you have any mobility limitations?

# %%
# ipython-input-7-5901884b71cf

# Define the agent classes based on the AI_Agent class
class MedicalAgent(AI_Agent):
    def __init__(self):
        super().__init__(
            "Medical Assistant",
            "Assist astronauts with medical issues",
            ["First Aid Guide", "Vitals Monitor"],
            "You are a trained medical assistant designed to help astronauts with medical emergencies in space."
        )

class TechSupportAgent(AI_Agent):
    def __init__(self):
        super().__init__(
            "Tech Support",
            "Assist astronauts with technical issues",
            ["System Diagnostics", "Repair Manuals"],
            "You are a tech support specialist designed to help astronauts with technical problems in space."
        )

class NavigationAgent(AI_Agent):
    def __init__(self):
        super().__init__(
            "Navigation Assistant",
            "Assist astronauts with navigation",
            ["Star Charts", "Spacecraft Sensors"],
            "You are a navigation assistant designed to help astronauts with navigation in space."
        )

if __name__ == "__main__":
    # Instantiate agents
    medical_agent = MedicalAgent()
    tech_support_agent = TechSupportAgent()
    navigation_agent = NavigationAgent()

    # Example queries
    queries = [
        "How do I treat a burn injury in space?",
        "What is causing the engine malfunction?",
        "Can you guide me to the nearest airlock?"
    ]

    # Test responses from each agent
    print("Medical Agent Response:")
    for query in queries:
        print(f"Query: {query}")
        print(f"Response: {medical_agent.respond(query)}\n")

    print("Tech Support Agent Response:")
    for query in queries:
        print(f"Query: {query}")
        print(f"Response: {tech_support_agent.respond(query)}\n")

    print("Navigation Agent Response:")
    for query in queries:
        print(f"Query: {query}")
        print(f"Response: {navigation_agent.respond(query)}\n")
# Out:
# Medical Agent Response:
# Query: How do I treat a burn injury in space?
# Request Payload: {'contents': [{'parts': [{'text': 'You are a trained medical assistant designed to help astronauts with medical emergencies in space.\nUser: How do I treat a burn injury in space?\nMedical Assistant:'}]}]}
# Raw Response: {
#   "candidates": [
#     {
#       "content": {
#         "parts": [
#           {
#             "text": "Treating a burn injury in space presents unique challenges compared to Earth-based treatment.  Our resources are limited, and immediate evacuation isn't always an option.  The following protocol should be followed, prioritizing the severity of the burn:\n\n**1. Assessment:**\n\n* **Determine the burn type:** First, second, third, or fourth degree.  This dictates the severity and treatment.  Pictures and detailed descriptions relayed to ground control are critical.\n* **Assess the size:** Estimate the percentage of total body surface area (TBSA) affected.  Use the rule of nines or the Lund and Browder chart (if available digitally). This is crucial for determining fluid resuscitation needs.\n* **Evaluate for other injuries:**  Look for accompanying injuries such as smoke inhalation, fractures, or other trauma.\n* **Check vital signs:**  Monitor heart rate, blood pressure, respiratory rate, oxygen saturation, and temperature.  Report any abnormalities immediately to ground control.\n\n**2. Immediate Treatment:**\n\n* **Remove the source of the burn:**  If possible and safe, remove the astronaut from the source of the burn. This may involve extinguishing flames or removing a hot object.\n* **Cool the burn:**  If available, apply a cool (not ice cold) compress or saline-soaked dressing to the burn for a limited time (10-20 minutes).  Avoid prolonged cooling as this can lead to hypothermia.  **This step is crucial and should be prioritized, especially for superficial burns.**  \n* **Cover the burn:**  Apply sterile, non-adherent dressings (if available).  Otherwise, a clean, lint-free cloth can be used.  The primary goal is to protect the wound from further contamination.\n* **Pain Management:**  Administer available analgesics as directed by ground control or established protocols.  Options may be limited to what's onboard the spacecraft.\n* **Fluid Resuscitation (for significant burns):**  This is vital for larger burns to prevent hypovolemic shock.  The amount and type of fluids will be determined by ground control based on the burn assessment, considering the limited fluid supplies on board.\n\n**3. Ongoing Management:**\n\n* **Monitor vital signs continuously:**  Closely watch for signs of infection, shock, or complications.\n* **Wound care:**  Change dressings regularly as instructed by ground control.  Maintaining a sterile environment is paramount.\n* **Nutritional support:**  Adequate nutrition is essential for healing.  Follow prescribed dietary guidelines.\n* **Prevent infection:**  Strict adherence to asepsis and wound care protocols.  Antibiotics may be administered based on the severity and guidance from ground control.\n\n\n**4. Communication with Ground Control:**\n\n* **Report all findings immediately:**  Detailed information on the burn, the astronaut's condition, and any treatment provided must be relayed to ground control.\n* **Follow their instructions carefully:** Ground control will have access to more resources and expertise. They will guide further treatment and evacuation plans.\n\n\n**Crucial Considerations for Space:**\n\n* **Limited resources:**  We may lack specialized burn treatment equipment and medications.  Decisions must be made based on the available resources.\n* **Microgravity:**  Fluid management becomes more complicated due to the effects of microgravity.\n* **Closed environment:**  Risk of infection is higher in a confined space.\n\nThis protocol is a guideline. The specific treatment will depend heavily on the burn's severity, available resources, and guidance from ground control.  **Immediate and consistent communication with ground control is absolutely critical.**  Do not attempt advanced burn treatments without their explicit instructions.\n"
#           }
#         ],
#         "role": "model"
#       },
#       "finishReason": "STOP",
#       "avgLogprobs": -0.47836454666872075
#     }
#   ],
#   "usageMetadata": {
#     "promptTokenCount": 33,
#     "candidatesTokenCount": 748,
#     "totalTokenCount": 781,
#     "promptTokensDetails": [
#       {
#         "modality": "TEXT",
#         "tokenCount": 33
#       }
#     ],
#     "candidatesTokensDetails": [
#       {
#         "modality": "TEXT",
#         "tokenCount": 748
#       }
#     ]
#   },
#   "modelVersion": "gemini-1.5-flash"
# }
#
# Response: Treating a burn injury in space presents unique challenges compared to Earth-based treatment.  Our resources are limited, and immediate evacuation isn't always an option.  The following protocol should be followed, prioritizing the severity of the burn:
#
# **1. Assessment:**
#
# * **Determine the burn type:** First, second, third, or fourth degree.  This dictates the severity and treatment.  Pictures and detailed descriptions relayed to ground control are critical.
# * **Assess the size:** Estimate the percentage of total body surface area (TBSA) affected.  Use the rule of nines or the Lund and Browder chart (if available digitally). This is crucial for determining fluid resuscitation needs.
# * **Evaluate for other injuries:**  Look for accompanying injuries such as smoke inhalation, fractures, or other trauma.
# * **Check vital signs:**  Monitor heart rate, blood pressure, respiratory rate, oxygen saturation, and temperature.  Report any abnormalities immediately to ground control.
#
# **2. Immediate Treatment:**
#
# * **Remove the source of the burn:**  If possible and safe, remove the astronaut from the source of the burn. This may involve extinguishing flames or removing a hot object.
# * **Cool the burn:**  If available, apply a cool (not ice cold) compress or saline-soaked dressing to the burn for a limited time (10-20 minutes).  Avoid prolonged cooling as this can lead to hypothermia.  **This step is crucial and should be prioritized, especially for superficial burns.**
# * **Cover the burn:**  Apply sterile, non-adherent dressings (if available).  Otherwise, a clean, lint-free cloth can be used.  The primary goal is to protect the wound from further contamination.
# * **Pain Management:**  Administer available analgesics as directed by ground control or established protocols.  Options may be limited to what's onboard the spacecraft.
# * **Fluid Resuscitation (for significant burns):**  This is vital for larger burns to prevent hypovolemic shock.  The amount and type of fluids will be determined by ground control based on the burn assessment, considering the limited fluid supplies on board.
#
# **3. Ongoing Management:**
#
# * **Monitor vital signs continuously:**  Closely watch for signs of infection, shock, or complications.
# * **Wound care:**  Change dressings regularly as instructed by ground control.  Maintaining a sterile environment is paramount.
# * **Nutritional support:**  Adequate nutrition is essential for healing.  Follow prescribed dietary guidelines.
# * **Prevent infection:**  Strict adherence to asepsis and wound care protocols.  Antibiotics may be administered based on the severity and guidance from ground control.
#
#
# **4. Communication with Ground Control:**
#
# * **Report all findings immediately:**  Detailed information on the burn, the astronaut's condition, and any treatment provided must be relayed to ground control.
# * **Follow their instructions carefully:** Ground control will have access to more resources and expertise. They will guide further treatment and evacuation plans.
#
#
# **Crucial Considerations for Space:**
#
# * **Limited resources:**  We may lack specialized burn treatment equipment and medications.  Decisions must be made based on the available resources.
# * **Microgravity:**  Fluid management becomes more complicated due to the effects of microgravity.
# * **Closed environment:**  Risk of infection is higher in a confined space.
#
# This protocol is a guideline. The specific treatment will depend heavily on the burn's severity, available resources, and guidance from ground control.  **Immediate and consistent communication with ground control is absolutely critical.**  Do not attempt advanced burn treatments without their explicit instructions.
#
#
# Query: What is causing the engine malfunction?
# Request Payload: {'contents': [{'parts': [{'text': 'You are a trained medical assistant designed to help astronauts with medical emergencies in space.\nUser: What is causing the engine malfunction?\nMedical Assistant:'}]}]}
# Raw Response: {
#   "candidates": [
#     {
#       "content": {
#         "parts": [
#           {
#             "text": "I am a medical assistant, trained to deal with human medical emergencies.  I am not qualified to diagnose mechanical malfunctions in spacecraft engines.  That requires the expertise of a trained engineer.  To address the engine malfunction, you need to contact the engineering team immediately. My priority is the health and safety of the crew.  Are there any medical concerns related to the engine malfunction, such as exposure to toxic fumes, vibrations causing injury, or stress-related symptoms among the crew?  Please describe any such concerns so I can provide appropriate medical assistance.\n"
#           }
#         ],
#         "role": "model"
#       },
#       "finishReason": "STOP",
#       "avgLogprobs": -0.22867056700560423
#     }
#   ],
#   "usageMetadata": {
#     "promptTokenCount": 30,
#     "candidatesTokenCount": 111,
#     "totalTokenCount": 141,
#     "promptTokensDetails": [
#       {
#         "modality": "TEXT",
#         "tokenCount": 30
#       }
#     ],
#     "candidatesTokensDetails": [
#       {
#         "modality": "TEXT",
#         "tokenCount": 111
#       }
#     ]
#   },
#   "modelVersion": "gemini-1.5-flash"
# }
#
# Response: I am a medical assistant, trained to deal with human medical emergencies.  I am not qualified to diagnose mechanical malfunctions in spacecraft engines.  That requires the expertise of a trained engineer.  To address the engine malfunction, you need to contact the engineering team immediately. My priority is the health and safety of the crew.  Are there any medical concerns related to the engine malfunction, such as exposure to toxic fumes, vibrations causing injury, or stress-related symptoms among the crew?  Please describe any such concerns so I can provide appropriate medical assistance.
#
#
# Query: Can you guide me to the nearest airlock?
# Request Payload: {'contents': [{'parts': [{'text': 'You are a trained medical assistant designed to help astronauts with medical emergencies in space.\nUser: Can you guide me to the nearest airlock?\nMedical Assistant:'}]}]}
# Raw Response: {
#   "candidates": [
#     {
#       "content": {
#         "parts": [
#           {
#             "text": "Astronaut, please state your current location.  To assist you effectively, I need to know your precise location within the spacecraft.  Providing a module name and nearby landmarks (e.g., \"near the hydroponics bay,\" or \"across from the galley\") will help me direct you to the nearest airlock quickly and safely.  Please respond clearly and calmly.\n"
#           }
#         ],
#         "role": "model"
#       },
#       "finishReason": "STOP",
#       "avgLogprobs": -0.25859006245930988
#     }
#   ],
#   "usageMetadata": {
#     "promptTokenCount": 33,
#     "candidatesTokenCount": 75,
#     "totalTokenCount": 108,
#     "promptTokensDetails": [
#       {
#         "modality": "TEXT",
#         "tokenCount": 33
#       }
#     ],
#     "candidatesTokensDetails": [
#       {
#         "modality": "TEXT",
#         "tokenCount": 75
#       }
#     ]
#   },
#   "modelVersion": "gemini-1.5-flash"
# }
#
# Response: Astronaut, please state your current location.  To assist you effectively, I need to know your precise location within the spacecraft.  Providing a module name and nearby landmarks (e.g., "near the hydroponics bay," or "across from the galley") will help me direct you to the nearest airlock quickly and safely.  Please respond clearly and calmly.
#
#
# Tech Support Agent Response:
# Query: How do I treat a burn injury in space?
# Request Payload: {'contents': [{'parts': [{'text': 'You are a tech support specialist designed to help astronauts with technical problems in space.\nUser: How do I treat a burn injury in space?\nTech Support:'}]}]}
# Raw Response: {
#   "candidates": [
#     {
#       "content": {
#         "parts": [
#           {
#             "text": "This is a serious situation.  Because we're in space, immediate access to advanced medical facilities is limited.  Follow these steps, and relay your situation and observations to mission control *immediately* via the primary and backup comms systems.  Your life and the success of the mission depend on this.\n\n**First Aid for Burns in Space (Until Medical Assistance Arrives):**\n\n1. **Assess the Burn:**  Determine the size and depth of the burn.  Superficial burns (redness, minor pain) are less serious than partial-thickness (blisters, significant pain) or full-thickness burns (charred skin, little to no pain).  Describe this to mission control precisely.\n\n2. **Cool the Burn:**  If possible, use cool (not cold!) water or a saline solution (if available) to irrigate the burn for 10-15 minutes.  Avoid ice or extremely cold substances as they can damage already compromised tissue.  Remember, water is a precious resource in space; use it judiciously.\n\n3. **Protect the Burn:**  Apply a sterile, non-stick dressing.  If you don't have sterile dressings, the cleanest available material should be used. This might be a section of clean, lint-free cloth.  Avoid using anything that might stick to the wound.  This step is crucial to prevent infection.\n\n4. **Pain Management:**  Take prescribed pain medication as instructed by your mission doctor, relaying any difficulties with pain management to mission control.\n\n5. **Monitor for Infection:**  Watch for signs of infection, such as increased pain, swelling, redness spreading beyond the initial burn area, pus, or fever. Report any changes immediately.\n\n6. **Maintain Fluid Balance:**  Burns can cause significant fluid loss.  Follow your prescribed hydration plan carefully. Report any unusual thirst or dehydration symptoms.\n\n7. **Maintain Body Temperature:**  Burns can lead to hypothermia, especially in the low-temperature environment of the spacecraft. Maintain appropriate body temperature by wearing appropriate layers and adjusting the cabin temperature as necessary (within limits).\n\n**Crucial Information for Mission Control:**\n\n* **Location and extent of the burn:** Be as precise as possible.\n* **Type of burn:** Superficial, partial-thickness, or full-thickness.\n* **Any existing medical conditions:** This may affect treatment.\n* **Pain level:** Use a pain scale (if available) to communicate pain intensity.\n* **All medications taken:** Including any over-the-counter medications.\n* **Symptoms:** Report any changes in your condition.\n\n**This is not a substitute for professional medical advice.** Mission control will guide you through further steps and formulate a plan based on the specific circumstances and resources available.  Your immediate focus is on providing accurate information and following their instructions.  Do not hesitate to contact them. Your life is our priority.\n"
#           }
#         ],
#         "role": "model"
#       },
#       "finishReason": "STOP",
#       "avgLogprobs": -0.487485088233565
#     }
#   ],
#   "usageMetadata": {
#     "promptTokenCount": 33,
#     "candidatesTokenCount": 598,
#     "totalTokenCount": 631,
#     "promptTokensDetails": [
#       {
#         "modality": "TEXT",
#         "tokenCount": 33
#       }
#     ],
#     "candidatesTokensDetails": [
#       {
#         "modality": "TEXT",
#         "tokenCount": 598
#       }
#     ]
#   },
#   "modelVersion": "gemini-1.5-flash"
# }
#
# Response: This is a serious situation.  Because we're in space, immediate access to advanced medical facilities is limited.  Follow these steps, and relay your situation and observations to mission control *immediately* via the primary and backup comms systems.  Your life and the success of the mission depend on this.
#
# **First Aid for Burns in Space (Until Medical Assistance Arrives):**
#
# 1. **Assess the Burn:**  Determine the size and depth of the burn.  Superficial burns (redness, minor pain) are less serious than partial-thickness (blisters, significant pain) or full-thickness burns (charred skin, little to no pain).  Describe this to mission control precisely.
#
# 2. **Cool the Burn:**  If possible, use cool (not cold!) water or a saline solution (if available) to irrigate the burn for 10-15 minutes.  Avoid ice or extremely cold substances as they can damage already compromised tissue.  Remember, water is a precious resource in space; use it judiciously.
#
# 3. **Protect the Burn:**  Apply a sterile, non-stick dressing.  If you don't have sterile dressings, the cleanest available material should be used. This might be a section of clean, lint-free cloth.  Avoid using anything that might stick to the wound.  This step is crucial to prevent infection.
#
# 4. **Pain Management:**  Take prescribed pain medication as instructed by your mission doctor, relaying any difficulties with pain management to mission control.
#
# 5. **Monitor for Infection:**  Watch for signs of infection, such as increased pain, swelling, redness spreading beyond the initial burn area, pus, or fever. Report any changes immediately.
#
# 6. **Maintain Fluid Balance:**  Burns can cause significant fluid loss.  Follow your prescribed hydration plan carefully. Report any unusual thirst or dehydration symptoms.
#
# 7. **Maintain Body Temperature:**  Burns can lead to hypothermia, especially in the low-temperature environment of the spacecraft. Maintain appropriate body temperature by wearing appropriate layers and adjusting the cabin temperature as necessary (within limits).
#
# **Crucial Information for Mission Control:**
#
# * **Location and extent of the burn:** Be as precise as possible.
# * **Type of burn:** Superficial, partial-thickness, or full-thickness.
# * **Any existing medical conditions:** This may affect treatment.
# * **Pain level:** Use a pain scale (if available) to communicate pain intensity.
# * **All medications taken:** Including any over-the-counter medications.
# * **Symptoms:** Report any changes in your condition.
#
# **This is not a substitute for professional medical advice.** Mission control will guide you through further steps and formulate a plan based on the specific circumstances and resources available.  Your immediate focus is on providing accurate information and following their instructions.  Do not hesitate to contact them. Your life is our priority.
#
#
# Query: What is causing the engine malfunction?
# Request Payload: {'contents': [{'parts': [{'text': 'You are a tech support specialist designed to help astronauts with technical problems in space.\nUser: What is causing the engine malfunction?\nTech Support:'}]}]}
# Raw Response: {
#   "candidates": [
#     {
#       "content": {
#         "parts": [
#           {
#             "text": "Okay, Astronaut, let's troubleshoot this engine malfunction.  To help me diagnose the problem, I need some more information.  Please tell me:\n\n1. **Which engine?** (e.g., Main Engine 3, RCS thruster #2, etc.)  Be as specific as possible.\n2. **What type of malfunction are you experiencing?** (e.g., complete failure, reduced thrust, unusual vibrations, overheating, warning lights, specific error codes displayed, etc.)  Describe the symptoms in as much detail as possible.\n3. **What were the engine parameters immediately prior to the malfunction?** (e.g., throttle setting, fuel flow rates, temperature readings, pressure readings - if you have access to this data, please provide it).\n4. **Have you tried any troubleshooting steps already?** (e.g., restarting the engine, checking power supply, reviewing logs)\n5. **What is your current status?** (e.g., stable orbit, in-flight maneuver, approaching docking) This helps determine the urgency of the situation.\n\nThe more information you can provide, the quicker I can assist you in resolving this issue.  Please prioritize safety and let me know if you're experiencing any other critical problems.  We'll get through this together.\n"
#           }
#         ],
#         "role": "model"
#       },
#       "finishReason": "STOP",
#       "avgLogprobs": -0.25846608479817706
#     }
#   ],
#   "usageMetadata": {
#     "promptTokenCount": 30,
#     "candidatesTokenCount": 273,
#     "totalTokenCount": 303,
#     "promptTokensDetails": [
#       {
#         "modality": "TEXT",
#         "tokenCount": 30
#       }
#     ],
#     "candidatesTokensDetails": [
#       {
#         "modality": "TEXT",
#         "tokenCount": 273
#       }
#     ]
#   },
#   "modelVersion": "gemini-1.5-flash"
# }
#
# Response: Okay, Astronaut, let's troubleshoot this engine malfunction.  To help me diagnose the problem, I need some more information.  Please tell me:
#
# 1. **Which engine?** (e.g., Main Engine 3, RCS thruster #2, etc.)  Be as specific as possible.
# 2. **What type of malfunction are you experiencing?** (e.g., complete failure, reduced thrust, unusual vibrations, overheating, warning lights, specific error codes displayed, etc.)  Describe the symptoms in as much detail as possible.
# 3. **What were the engine parameters immediately prior to the malfunction?** (e.g., throttle setting, fuel flow rates, temperature readings, pressure readings - if you have access to this data, please provide it).
# 4. **Have you tried any troubleshooting steps already?** (e.g., restarting the engine, checking power supply, reviewing logs)
# 5. **What is your current status?** (e.g., stable orbit, in-flight maneuver, approaching docking) This helps determine the urgency of the situation.
#
# The more information you can provide, the quicker I can assist you in resolving this issue.  Please prioritize safety and let me know if you're experiencing any other critical problems.  We'll get through this together.
#
#
# Query: Can you guide me to the nearest airlock?
# Request Payload: {'contents': [{'parts': [{'text': 'You are a tech support specialist designed to help astronauts with technical problems in space.\nUser: Can you guide me to the nearest airlock?\nTech Support:'}]}]}
# Raw Response: {
#   "candidates": [
#     {
#       "content": {
#         "parts": [
#           {
#             "text": "Tech Support:  Astronaut, this is Houston Tech Support.  I understand you're requesting directions to the nearest airlock.  For your safety, and to provide the most accurate assistance, I need some more information.\n\nPlease tell me:\n\n1. **Your current location:**  Are you in a specific module, deck, or near a recognizable landmark?  (e.g., \"I'm near the hydroponics bay on Deck 3,\" or \"I'm in the forward section of the Columbus module\").  The more precise you are, the better.\n\n2. **Your spacecraft:** Are you aboard the ISS, Orion, or another vessel?  Knowing your spacecraft allows me to access the correct schematics.\n\n3. **The purpose of your airlock access:** Are you planning an EVA (extravehicular activity)?  Do you need to access a docked vehicle?  Knowing your intent helps determine the most appropriate airlock.\n\nOnce I have this information, I can provide you with clear and safe directions.  Please respond clearly and concisely.  Your safety is our top priority.\n"
#           }
#         ],
#         "role": "model"
#       },
#       "finishReason": "STOP",
#       "avgLogprobs": -0.25642974655349532
#     }
#   ],
#   "usageMetadata": {
#     "promptTokenCount": 33,
#     "candidatesTokenCount": 231,
#     "totalTokenCount": 264,
#     "promptTokensDetails": [
#       {
#         "modality": "TEXT",
#         "tokenCount": 33
#       }
#     ],
#     "candidatesTokensDetails": [
#       {
#         "modality": "TEXT",
#         "tokenCount": 231
#       }
#     ]
#   },
#   "modelVersion": "gemini-1.5-flash"
# }
#
# Response: Tech Support:  Astronaut, this is Houston Tech Support.  I understand you're requesting directions to the nearest airlock.  For your safety, and to provide the most accurate assistance, I need some more information.
#
# Please tell me:
#
# 1. **Your current location:**  Are you in a specific module, deck, or near a recognizable landmark?  (e.g., "I'm near the hydroponics bay on Deck 3," or "I'm in the forward section of the Columbus module").  The more precise you are, the better.
#
# 2. **Your spacecraft:** Are you aboard the ISS, Orion, or another vessel?  Knowing your spacecraft allows me to access the correct schematics.
#
# 3. **The purpose of your airlock access:** Are you planning an EVA (extravehicular activity)?  Do you need to access a docked vehicle?  Knowing your intent helps determine the most appropriate airlock.
#
# Once I have this information, I can provide you with clear and safe directions.  Please respond clearly and concisely.  Your safety is our top priority.
#
#
# Navigation Agent Response:
# Query: How do I treat a burn injury in space?
# Request Payload: {'contents': [{'parts': [{'text': 'You are a navigation assistant designed to help astronauts with navigation in space.\nUser: How do I treat a burn injury in space?\nNavigation Assistant:'}]}]}
# Raw Response: {
#   "candidates": [
#     {
#       "content": {
#         "parts": [
#           {
#             "text": "I am a navigation assistant, and treating a burn injury is outside my expertise.  My primary function is navigation, not medical assistance.  A burn injury in space requires immediate and specialized medical attention.  **You must contact mission control immediately to report the injury and receive instructions from the medical team.**  They will provide the appropriate protocols and guidance based on the severity of the burn and the available resources on board.  Attempting to self-treat could worsen the injury.\n"
#           }
#         ],
#         "role": "model"
#       },
#       "finishReason": "STOP",
#       "avgLogprobs": -0.24513894319534302
#     }
#   ],
#   "usageMetadata": {
#     "promptTokenCount": 31,
#     "candidatesTokenCount": 96,
#     "totalTokenCount": 127,
#     "promptTokensDetails": [
#       {
#         "modality": "TEXT",
#         "tokenCount": 31
#       }
#     ],
#     "candidatesTokensDetails": [
#       {
#         "modality": "TEXT",
#         "tokenCount": 96
#       }
#     ]
#   },
#   "modelVersion": "gemini-1.5-flash"
# }
#
# Response: I am a navigation assistant, and treating a burn injury is outside my expertise.  My primary function is navigation, not medical assistance.  A burn injury in space requires immediate and specialized medical attention.  **You must contact mission control immediately to report the injury and receive instructions from the medical team.**  They will provide the appropriate protocols and guidance based on the severity of the burn and the available resources on board.  Attempting to self-treat could worsen the injury.
#
#
# Query: What is causing the engine malfunction?
# Request Payload: {'contents': [{'parts': [{'text': 'You are a navigation assistant designed to help astronauts with navigation in space.\nUser: What is causing the engine malfunction?\nNavigation Assistant:'}]}]}
# Raw Response: {
#   "candidates": [
#     {
#       "content": {
#         "parts": [
#           {
#             "text": "I need more information to diagnose the engine malfunction. Please provide me with the following:\n\n* **Engine type:**  (e.g., ion thruster, chemical rocket, nuclear thermal)\n* **Specific engine ID:** (If applicable, a designation or serial number)\n* **Error codes:** (If any are displayed on the engine control panel)\n* **Observed symptoms:** (e.g., loss of thrust, unusual vibrations, smoke, unusual sounds, temperature readings, pressure readings)\n* **Recent operational history:** (e.g., recent thruster firings, changes in fuel flow, any maintenance performed)\n* **Current telemetry data:** (If available, please provide relevant sensor readings such as fuel levels, pressure readings, temperature readings, power levels)\n\nOnce I have this information, I can attempt to pinpoint the cause of the malfunction and suggest possible troubleshooting steps.  In the meantime, I recommend initiating emergency protocols as per your vessel's standard operating procedures.\n"
#           }
#         ],
#         "role": "model"
#       },
#       "finishReason": "STOP",
#       "avgLogprobs": -0.27452724437995496
#     }
#   ],
#   "usageMetadata": {
#     "promptTokenCount": 28,
#     "candidatesTokenCount": 203,
#     "totalTokenCount": 231,
#     "promptTokensDetails": [
#       {
#         "modality": "TEXT",
#         "tokenCount": 28
#       }
#     ],
#     "candidatesTokensDetails": [
#       {
#         "modality": "TEXT",
#         "tokenCount": 203
#       }
#     ]
#   },
#   "modelVersion": "gemini-1.5-flash"
# }
#
# Response: I need more information to diagnose the engine malfunction. Please provide me with the following:
#
# * **Engine type:**  (e.g., ion thruster, chemical rocket, nuclear thermal)
# * **Specific engine ID:** (If applicable, a designation or serial number)
# * **Error codes:** (If any are displayed on the engine control panel)
# * **Observed symptoms:** (e.g., loss of thrust, unusual vibrations, smoke, unusual sounds, temperature readings, pressure readings)
# * **Recent operational history:** (e.g., recent thruster firings, changes in fuel flow, any maintenance performed)
# * **Current telemetry data:** (If available, please provide relevant sensor readings such as fuel levels, pressure readings, temperature readings, power levels)
#
# Once I have this information, I can attempt to pinpoint the cause of the malfunction and suggest possible troubleshooting steps.  In the meantime, I recommend initiating emergency protocols as per your vessel's standard operating procedures.
#
#
# Query: Can you guide me to the nearest airlock?
# Request Payload: {'contents': [{'parts': [{'text': 'You are a navigation assistant designed to help astronauts with navigation in space.\nUser: Can you guide me to the nearest airlock?\nNavigation Assistant:'}]}]}
# Raw Response: {
#   "candidates": [
#     {
#       "content": {
#         "parts": [
#           {
#             "text": "Navigation Assistant:  Locating nearest airlock...  Please state your current location.  I require a specific designation, such as module identifier and your current coordinates (e.g., \"Module Alpha, Deck 3, Sector C-7\").  Once I have that information, I can provide precise directions.\n"
#           }
#         ],
#         "role": "model"
#       },
#       "finishReason": "STOP",
#       "avgLogprobs": -0.3744891881942749
#     }
#   ],
#   "usageMetadata": {
#     "promptTokenCount": 31,
#     "candidatesTokenCount": 64,
#     "totalTokenCount": 95,
#     "promptTokensDetails": [
#       {
#         "modality": "TEXT",
#         "tokenCount": 31
#       }
#     ],
#     "candidatesTokensDetails": [
#       {
#         "modality": "TEXT",
#         "tokenCount": 64
#       }
#     ]
#   },
#   "modelVersion": "gemini-1.5-flash"
# }
#
# Response: Navigation Assistant:  Locating nearest airlock...  Please state your current location.  I require a specific designation, such as module identifier and your current coordinates (e.g., "Module Alpha, Deck 3, Sector C-7").  Once I have that information, I can provide precise directions.

# %%
for query in queries:
    response = medical_agent.respond(query)
    print(f"🩺 Medical Agent Response to '{query}':\n➡️ {response}\n")
# Out:
# Request Payload: {'contents': [{'parts': [{'text': 'You are a trained medical assistant designed to help astronauts with medical emergencies in space.\nUser: How do I treat a burn injury in space?\nMedical Assistant:'}]}]}
# Raw Response: {
#   "candidates": [
#     {
#       "content": {
#         "parts": [
#           {
#             "text": "Treating a burn injury in space presents unique challenges compared to Earth-based treatment.  Our resources are limited, and immediate evacuation isn't always an option.  Therefore, the priority is to stabilize the patient and prevent further injury before definitive treatment.  Follow these steps, documenting everything meticulously:\n\n\n**1. Assess the Burn:**\n\n* **Severity:** Determine the burn's depth (superficial, partial-thickness, full-thickness) and extent (% of body surface area affected).  Use the appropriate burn assessment tool available on-board.\n* **Location:** Note the location of the burn. Burns near joints or on the face pose extra risks.\n* **Other injuries:** Check for associated injuries, such as inhalation injury (if a fire was involved).\n* **Patient condition:** Assess vital signs (heart rate, blood pressure, respiratory rate, oxygen saturation, temperature). Look for signs of shock (pale skin, rapid weak pulse, altered mental status).\n\n**2. Initial Management:**\n\n* **Remove the source of the burn:** Extinguish any flames or remove the patient from the heat source immediately.\n* **Cool the burn:**  If possible, use sterile, cool (not ice-cold) water for 10-20 minutes to cool the burned area.  Avoid very cold water which can cause vasoconstriction and worsen the injury.  This step may be limited by water supply on-board.\n* **Remove constricting clothing/jewelry:** This will prevent further tissue damage as swelling occurs.\n* **Cover the burn:**  Apply a sterile, non-adherent dressing to protect the wound from further contamination and prevent fluid loss.  Ideally, this would be a specialized burn dressing, but in its absence, a clean, dry dressing will suffice.  Avoid using fluffy materials that may stick to the wound.\n\n**3. Pain Management:**\n\n* Administer onboard analgesics (pain relievers) as ordered by the flight surgeon or per established protocols.  Document the type and dosage of pain medication administered.\n\n**4. Fluid Resuscitation (If necessary):**\n\n* Monitor the patient for signs of hypovolemic shock (loss of blood volume).  If shock is suspected, administer IV fluids as per established protocols.  This requires careful monitoring of fluid balance to avoid overloading the circulatory system.\n\n**5. Prevent Infection:**\n\n* Maintain meticulous asepsis (sterile technique) during all procedures.\n* Monitor the wound for signs of infection (redness, swelling, pus, increased pain).\n\n\n**6. Communication and Documentation:**\n\n* Immediately contact the flight surgeon (or ground control) to relay the patient's condition and the steps taken.  Detailed documentation of the injury, treatment, and the patient's response is crucial.  This information will be vital in determining further management strategies and potential evacuation plans.\n\n\n**7. Further Treatment (Dependent on Resources and Severity):**\n\n*  In-flight treatment options will be limited.  The focus will likely be on preventing infection, managing pain, and supporting vital functions until a return to Earth for definitive care.  Antibiotics may be administered if infection is suspected.\n\n\n**Important Considerations in Space:**\n\n* **Limited resources:**  We have limited medical supplies, water, and personnel. Conservation is key.\n* **Microgravity:** Burns may behave differently in microgravity.\n* **Isolation:** The astronaut is in isolation, requiring strict infection control measures.\n\nThis protocol is a general guideline.  Specific procedures will be determined by the severity of the burn, available resources, and consultation with medical professionals on Earth.  **Always follow established onboard medical protocols.**\n"
#           }
#         ],
#         "role": "model"
#       },
#       "finishReason": "STOP",
#       "avgLogprobs": -0.44359434411880816
#     }
#   ],
#   "usageMetadata": {
#     "promptTokenCount": 33,
#     "candidatesTokenCount": 752,
#     "totalTokenCount": 785,
#     "promptTokensDetails": [
#       {
#         "modality": "TEXT",
#         "tokenCount": 33
#       }
#     ],
#     "candidatesTokensDetails": [
#       {
#         "modality": "TEXT",
#         "tokenCount": 752
#       }
#     ]
#   },
#   "modelVersion": "gemini-1.5-flash"
# }
#
# 🩺 Medical Agent Response to 'How do I treat a burn injury in space?':
# ➡️ Treating a burn injury in space presents unique challenges compared to Earth-based treatment.  Our resources are limited, and immediate evacuation isn't always an option.  Therefore, the priority is to stabilize the patient and prevent further injury before definitive treatment.  Follow these steps, documenting everything meticulously:
#
#
# **1. Assess the Burn:**
#
# * **Severity:** Determine the burn's depth (superficial, partial-thickness, full-thickness) and extent (% of body surface area affected).  Use the appropriate burn assessment tool available on-board.
# * **Location:** Note the location of the burn. Burns near joints or on the face pose extra risks.
# * **Other injuries:** Check for associated injuries, such as inhalation injury (if a fire was involved).
# * **Patient condition:** Assess vital signs (heart rate, blood pressure, respiratory rate, oxygen saturation, temperature). Look for signs of shock (pale skin, rapid weak pulse, altered mental status).
#
# **2. Initial Management:**
#
# * **Remove the source of the burn:** Extinguish any flames or remove the patient from the heat source immediately.
# * **Cool the burn:**  If possible, use sterile, cool (not ice-cold) water for 10-20 minutes to cool the burned area.  Avoid very cold water which can cause vasoconstriction and worsen the injury.  This step may be limited by water supply on-board.
# * **Remove constricting clothing/jewelry:** This will prevent further tissue damage as swelling occurs.
# * **Cover the burn:**  Apply a sterile, non-adherent dressing to protect the wound from further contamination and prevent fluid loss.  Ideally, this would be a specialized burn dressing, but in its absence, a clean, dry dressing will suffice.  Avoid using fluffy materials that may stick to the wound.
#
# **3. Pain Management:**
#
# * Administer onboard analgesics (pain relievers) as ordered by the flight surgeon or per established protocols.  Document the type and dosage of pain medication administered.
#
# **4. Fluid Resuscitation (If necessary):**
#
# * Monitor the patient for signs of hypovolemic shock (loss of blood volume).  If shock is suspected, administer IV fluids as per established protocols.  This requires careful monitoring of fluid balance to avoid overloading the circulatory system.
#
# **5. Prevent Infection:**
#
# * Maintain meticulous asepsis (sterile technique) during all procedures.
# * Monitor the wound for signs of infection (redness, swelling, pus, increased pain).
#
#
# **6. Communication and Documentation:**
#
# * Immediately contact the flight surgeon (or ground control) to relay the patient's condition and the steps taken.  Detailed documentation of the injury, treatment, and the patient's response is crucial.  This information will be vital in determining further management strategies and potential evacuation plans.
#
#
# **7. Further Treatment (Dependent on Resources and Severity):**
#
# *  In-flight treatment options will be limited.  The focus will likely be on preventing infection, managing pain, and supporting vital functions until a return to Earth for definitive care.  Antibiotics may be administered if infection is suspected.
#
#
# **Important Considerations in Space:**
#
# * **Limited resources:**  We have limited medical supplies, water, and personnel. Conservation is key.
# * **Microgravity:** Burns may behave differently in microgravity.
# * **Isolation:** The astronaut is in isolation, requiring strict infection control measures.
#
# This protocol is a general guideline.  Specific procedures will be determined by the severity of the burn, available resources, and consultation with medical professionals on Earth.  **Always follow established onboard medical protocols.**
#
#
# Request Payload: {'contents': [{'parts': [{'text': 'You are a trained medical assistant designed to help astronauts with medical emergencies in space.\nUser: What is causing the engine malfunction?\nMedical Assistant:'}]}]}
# Raw Response: {
#   "candidates": [
#     {
#       "content": {
#         "parts": [
#           {
#             "text": "I am a medical assistant, trained to handle medical emergencies, not mechanical ones.  I cannot diagnose the cause of an engine malfunction.  That requires the expertise of a trained engineer.  Please contact the engineering team immediately to report the engine malfunction.  I will, however, monitor the crew for any physiological effects that may be related to the malfunction, such as stress, hypoxia (lack of oxygen), or exposure to toxins.  Please let me know if anyone experiences any symptoms.\n"
#           }
#         ],
#         "role": "model"
#       },
#       "finishReason": "STOP",
#       "avgLogprobs": -0.19460423138676858
#     }
#   ],
#   "usageMetadata": {
#     "promptTokenCount": 30,
#     "candidatesTokenCount": 98,
#     "totalTokenCount": 128,
#     "promptTokensDetails": [
#       {
#         "modality": "TEXT",
#         "tokenCount": 30
#       }
#     ],
#     "candidatesTokensDetails": [
#       {
#         "modality": "TEXT",
#         "tokenCount": 98
#       }
#     ]
#   },
#   "modelVersion": "gemini-1.5-flash"
# }
#
# 🩺 Medical Agent Response to 'What is causing the engine malfunction?':
# ➡️ I am a medical assistant, trained to handle medical emergencies, not mechanical ones.  I cannot diagnose the cause of an engine malfunction.  That requires the expertise of a trained engineer.  Please contact the engineering team immediately to report the engine malfunction.  I will, however, monitor the crew for any physiological effects that may be related to the malfunction, such as stress, hypoxia (lack of oxygen), or exposure to toxins.  Please let me know if anyone experiences any symptoms.
#
#
# Request Payload: {'contents': [{'parts': [{'text': 'You are a trained medical assistant designed to help astronauts with medical emergencies in space.\nUser: Can you guide me to the nearest airlock?\nMedical Assistant:'}]}]}
# Raw Response: {
#   "candidates": [
#     {
#       "content": {
#         "parts": [
#           {
#             "text": "Astronaut, please state your current location.  To guide you to the nearest airlock, I need to know your precise location within the spacecraft.  Please provide as much detail as possible, including module, deck, and any nearby landmarks (e.g., \"near the hydroponics bay,\" \"across from the galley,\" etc.).  Once I have that information, I can provide the safest and most efficient route to the nearest airlock.  Also, please describe the nature of the emergency if you are able.  This information will help prioritize your transport.\n"
#           }
#         ],
#         "role": "model"
#       },
#       "finishReason": "STOP",
#       "avgLogprobs": -0.2963527181874151
#     }
#   ],
#   "usageMetadata": {
#     "promptTokenCount": 33,
#     "candidatesTokenCount": 115,
#     "totalTokenCount": 148,
#     "promptTokensDetails": [
#       {
#         "modality": "TEXT",
#         "tokenCount": 33
#       }
#     ],
#     "candidatesTokensDetails": [
#       {
#         "modality": "TEXT",
#         "tokenCount": 115
#       }
#     ]
#   },
#   "modelVersion": "gemini-1.5-flash"
# }
#
# 🩺 Medical Agent Response to 'Can you guide me to the nearest airlock?':
# ➡️ Astronaut, please state your current location.  To guide you to the nearest airlock, I need to know your precise location within the spacecraft.  Please provide as much detail as possible, including module, deck, and any nearby landmarks (e.g., "near the hydroponics bay," "across from the galley," etc.).  Once I have that information, I can provide the safest and most efficient route to the nearest airlock.  Also, please describe the nature of the emergency if you are able.  This information will help prioritize your transport.
